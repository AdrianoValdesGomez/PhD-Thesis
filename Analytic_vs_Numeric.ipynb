# %% [markdown]
# # CODE

# %%
# coding: utf-8
import numpy as np
from matplotlib import pyplot as plt
def orto(x):
    if np.dot(x,x) == 0:
        return 'No se puede: ese es el vector cero!'
    else:
        if 0 not in x:
            v1 = 1
            v2 = -(x[0]/x[1])
            v3 = 0
            #return np.array([v1,v2,v3])
        else:
            if x[0] == 0:
                if x[1] == 0:
                    v1 = 1
                    v2 = 0
                    v3 = 0
                else:
                    v1 = 0
                    v2 = 0
                    v3 = 1
            elif x[1] == 0:
                v1 = 0
                v2 = 1
                v3 = 0
            else:
                v1 = 0
                v2 = 0
                v3 = 1
        return np.array([v1,v2,v3])
    
#Funcion que regresa dos vectores; numpy arrays de 3D, ortogonales al vector de input x.
#Esto es, devuelven la base al espacio ortogonal definido por el vector x de entrada.
#@jit
def base_ort_nor(x):
    y = orto(x)
    v1 = y/np.linalg.norm(y)
    z = np.cross(x,v1)
    v2 = z/np.linalg.norm(z)
    return v1, v2


#Esta funcion genera un vector con distrubucion uniforme en las direcciones sobre un plano tangente a la esfera de radio R.
#@jit
def vector_des(v1,v2):
    na = 2*np.pi*np.random.rand()
    vn = v1*np.cos(na) + v2*np.sin(na)
    return vn/np.linalg.norm(vn)

R = 1.

#Normalizamos al vector de desplazamiento para que intersecte al vector de la nueva posicion de acuerdo con que el
#desplazamiento (s) sobre la esfera, sobre este arco de circulo maximo, sea el determinado por el movimiento browniano particular.
#@jit
def vector_q(x,s):
    q = (R)*np.tan(s/(R))
    return q*x

#Dados todos los datos anteriores, esta funcion actualiza la posicion de la particula.
#Lo que hace es que la mueve sobre el plano tangente a la esfera en la direccion predeterminada de tal suerte que el desplazamiento efectivo
#s sobre una geodesica de la esfera, se el deseado, y posteriormente la proyecta sobre la superficie de la esfera.
#@jit
def nuevo_r(r, vector_q):
    y = r + vector_q
    y = y/np.linalg.norm(y)
    return (R)*y

#funcion que incorpora el efecto de un campo externo



#Esta funcion ensambla todo lo anterior: como imput necesita una posicion inicial y un arco de desplazamiento
#Como output da un vector de posicion nuevo dada un tipo de desplazamiento.
#@jit
def actualiza(r,s):
    v1, v2 = base_ort_nor(r)
    pre_q = vector_des(v1,v2)
    q = vector_q(pre_q, s)
    return nuevo_r(r, q)




#Esta funcion actualiza la posicion de todos los elementos de una lista; particula brownianas.
#@jit


def act_n(lista, D, delta_t):
    l = []
    for v in lista:
        s = ese(D,delta_t)
        l.append(actualiza(v,s))
    return l



#Huella de la trayectoria
#La siguiente funcion hace una particion de la trayectoria sobre s en n pedazos y regresa
#una lista de los vectores de esas posiciones sobre la esfera.
#Usa al operador de rotacion.

#@jit
def b_steps_(ri,rf,n):
    l = [ri]
    r0 = ri
    lamb = (np.dot(ri,rf))/((np.linalg.norm(ri))*(np.linalg.norm(rf)))
    
    if abs(lamb) > 1:
        #print 'Is fucked up: there was a rounding '
        if lamb < 0:
            lamb = -1
        else:
            lamb = 1
    
    
    
    theta = np.arccos(lamb)
    #if theta < 1e17:
        #return l
    if theta == 0:
        return [ri,rf]
    
    else:

        normal = np.cross(ri, rf)/ np.linalg.norm(np.cross(ri,rf))
        for i in range(1,n + 1):
            #vi = rot_theta(r0, theta/n, normal)
            vi = rot_finita(r0, -normal, theta/n)
            l.append(vi)
            r0 = vi
        return l


#Operador de Rotacion
#Depende de los parametros r, el vector o punto que queremos rotar; theta el angulo de rotacion; n el vector que define el eje de rotacion y el signo de rotacion.


#@jit
def rot_theta(r, theta, u):
    x = np.array([np.cos(theta) + (u[0]*u[0])*(1 - np.cos(theta)), u[0]*u[1]*(1 - np.cos(theta)) - u[2]*np.sin(theta), u[0]*u[2]*(1 - np.cos(theta)) + u[1]*np.sin(theta)])
    y = np.array([u[1]*u[0]*(1 - np.cos(theta)) + u[2]*np.sin(theta), np.cos(theta) + u[1]*u[1]*(1 - np.cos(theta)), u[1]*u[2]*(1 - np.cos(theta)) - u[0]*np.sin(theta)])
    z = np.array([u[2]*u[0]*(1 - np.cos(theta)) - u[1]*np.sin(theta), u[2]*u[1]*(1 - np.cos(theta)) + u[0]*np.sin(theta), np.cos(theta) + u[2]*u[2]*(1 - np.cos(theta))])
    R = np.array([x,y,z])
    return np.dot(R, r)



#Transformacion de coordenada de esfericas a cartesianas.

#@jit
def trans_s_c(r,theta, phi):
    x = r*np.sin(theta)*np.cos(phi)
    y = r*np.sin(theta)* np.sin(phi)
    z = r*np.cos(theta)
    return x, y, z



def trans_c_s(x,y,z):
    r = np.sqrt(x**2 + y**2 + z**2)
    #print r
    cociente = z/r
    if abs(cociente) > 1:
        if cociente < 0:
            theta = np.arccos(-1.)
        else:
            theta = np.arccos(1.)
    else:
        
        theta = np.arccos(z/r)
    #Aqui hay un problema relevante: cada vez que y o x sean nulos, habra un problema
    #de indefinicion de operacion
    if x == 0.:
        if y == 0.:
            phi = 2*np.pi*np.random.rand()
    else:
        if x < 0:
            phi = np.arctan(y/x) + np.pi
        else:
            if y < 0:
                phi = np.arctan(y/x) + 2*np.pi
            else:
                
                phi = np.arctan(y/x)
    return r, theta, phi




#Base unitaria para las coordenadas esféricas
#@jit
def r_uni(theta, phi):
    x = np.sin(theta)*np.cos(phi)
    y = np.cos(theta)*np.cos(phi)
    z = np.cos(theta)
    return np.array([x,y,z])
#@jit
def theta_uni(theta, phi):
    x = np.cos(theta)*np.cos(phi)
    y = np.cos(theta)*np.sin(phi)
    z = -np.sin(theta)
    return np.array([x,y,z])
#@jit
def phi_uni(theta, phi):
    x = -np.sin(phi)
    y = np.cos(phi)
    z = 0
    return np.array([x,y,z])

#Función que normaliza los nombres para las animaciones de tal suerte que tenga el mismo número de
#digitos y se iteren en orden
#@jit
def nombre(s):
    diferencia = 4 - len(str(s))
    ceros = '' 
    for i in range(diferencia):
        ceros = ceros + '0'
    variable = ceros + str(s)
    return variable

#Varianza para una distribucion bigaussiana; difusion en 2D
#@jit
def var(D, delta_t):
    return 4*D*delta_t


#Arco de circulo maximo con distribucion normal alrededor de cero y una varianza dada por
#@jit
def ese(D,delta_t):
    return abs(np.random.normal(loc = 0., scale = np.sqrt(var(D,delta_t)),size = None))

#Funcion de rotacion finita
#@jit
def rot_finita(r_ini, N, Phi):
    n = N/np.linalg.norm(N)
    r_fin = np.cos(Phi)*r_ini + (np.dot(n,r_ini))*(1 - np.cos(Phi))*n + (np.sin(Phi))*(np.cross(r_ini,n))
    return r_fin


#Funcion que regresa una lista de n numpy arrays que son l
def Trayectoria(ri,rf,n):
    l = [ri]
    r0 = ri
    theta = np.arccos((np.dot(ri,rf))/((np.linalg.norm(ri))*(np.linalg.norm(rf))))
    N = np.cross(ri, rf)
    
    for i in range(1,n + 1):
        vi = rot_finita(r0, N, theta/n)
        l.append(vi)
        r0 = vi
    return l

#Collision_check es una función que, dada una trayectoria: una lista de vectores que
#pasan por puntos sucesivos de la trayectoria, verifica si alguna de estas posiciones
#interesecto a alguno de los obstáculos. En caso de que así sea, actualiza conforme una
#colision elastica. En caso de no intersectar a ningun obstaculo regresa una lista
#con dos vectores: posicion inicial y posicion final en ese orden.
#@jit
def penetrate_obs(lista_vect, lista_obs, size):
    metiches = []
    for obs in lista_obs:
        theta_omega = size
        r_omega = obs
        frontera = .2
        #metiches = []
        for v in lista_vect:
            tamanho = np.cos(theta_omega - frontera)
            if np.dot(v,r_omega) > tamanho:
                print('Penetro el mother fucker obstacle')
                metiches.append(v)
                
            else:
                continue
    #print 'no choco el mother fucker'
    #valor = False
    return metiches


#Esta funcion cuando es llamada grafia la posicion de las partoculas brownianas.
#sobre la superficie de una esfera sobre la que se esta difundiendo.
#@jit
def plot_particles(lista, vpolar, vazim, numero):
    from mpl_toolkits.mplot3d import axes3d
    from mpl_toolkits.mplot3d import Axes3D
    from matplotlib import cm

    #import matplotlib.pyplot as plt
    #import numpy as np
    from itertools import product, combinations
    fig = plt.figure(figsize=(8,8))
    ax = fig.gca(projection='3d')
    ax.set_aspect("equal")
    ax._axis3don = False

    



    #draw sphere
    R = 1
    u, v = np.mgrid[0:2*np.pi:50j, 0:np.pi:50j]
    x=R*np.cos(u)*np.sin(v)
    y=R*np.sin(u)*np.sin(v)
    z=R*np.cos(v)
    #ax.plot_surface(x, y, z, color="r", alpha = 0.15)

    ax.plot_surface(x, y, z, cmap=cm.YlGnBu_r,rstride=1, cstride=1, alpha = 0.10, linewidth = 0.10)
    ax.view_init(vpolar, vazim)
    
    
    #draw an arrow or a set of arrow
    #ax.quiver(0,0,1.5,0,0,1, length=0.5, arrow_length_ratio = .5, color = "b")
    #ax.quiver(1.5,0,0,1,0,0, length=0.5, arrow_length_ratio = .5, color ="g")
    #ax.quiver(0,1.5,0,0,1,0, length=0.5, arrow_length_ratio = .5, color ="r")
    #draw patch
    #u, v = np.mgrid[0:2*np.pi:50j, 0:(np.pi/7):50j]
    #x=R*np.cos(u)*np.sin(v)
    #y=R*np.sin(u)*np.sin(v)
    #z=R*np.cos(v)
    #ax.plot_surface(x, y, z, color="r", alpha = 0.25)    
    
    #draw points
    for p in lista:
        ax.scatter([p[0]],[p[1]],[p[2]],color="b",s=15, alpha = 0.25)
    
    fig.savefig('Sim_free_diff_Img{}.png'.format(nombre(numero)))
    #ax.view_init(80, 30)
    #plt.show()
    plt.close()

    
    
#@jit
def polo_n(n, R):
    l = []
    for i in range(n):
        l.append(np.array([0,0,R]))
    return l

#@jit
def particion_esfera(ccero, Nphi):
    Ntheta = int(4*np.pi/(ccero*Nphi))
    print('Ntheta', Ntheta, 'Nphi', Nphi, 'Ntheta*Nphi', Ntheta*Nphi)
    sigmaPhi = 2*np.pi/Nphi
    deltaphi = 2*np.pi/Nphi
    thetas = []
    phis = [0]
    cociente = ccero/sigmaPhi
    for i in range(Ntheta + 1):
        theta = np.arccos(1 - (i)*cociente)
        thetas.append(theta)
    for j in range(Nphi):
        phis.append(phis[j] + deltaphi)
    return thetas, phis

#@jit
def secuencia_part(tamini, Nfi, numero):
    l1, l2 = particion_esfera(4*np.pi/tamini, Nfi)
    particion = []
    for i in range(len(l2)):
        for j in range(len(l1)):
            x, y, z = trans_s_c(1, l1[j], l2[i])
            particion.append(np.array([x, y, z]))
            
    return plot_particles(particion, 45, 45, numero)

#Funcion que regresa las coordenadas del centro de dos arreglos para 
#las coordenadas theta y phi
#@jit
def coordenadas_centro(l1,l2):
    thetas_centro = []
    phis_centro = []
    for i in range(len(l1) - 1):
        theta_media = l1[i] + (l1[i + 1] - l1[i])/2.
        thetas_centro.append(theta_media)
    for j in range(len(l2) - 1):
        phi_media = l2[j] + (l2[j + 1] - l2[j])/2.
        phis_centro.append(phi_media)
    return thetas_centro, phis_centro

#@jit(nopython=True)
def secuencia_obs(N, Nfi, numero):
    l1_prima, l2_prima = particion_esfera(4*np.pi/N, Nfi)
    l1, l2 = coordenadas_centro(l1_prima, l2_prima)
    particion = []
    for i in range(len(l2)):
        for j in range(len(l1)):
            x, y, z = trans_s_c(1, l1[j], l2[i])
            particion.append(np.array([x, y, z]))
            
    print(len(particion))
    
    #return plot_particles(particion, 0, 0, numero)
    return particion


def plot_particle_traj_obs(lista_obstaculos, trayectoria,  vpolar, vazim, numero):
    from mpl_toolkits.mplot3d import axes3d
    from mpl_toolkits.mplot3d import Axes3D
    from matplotlib import cm

    #import matplotlib.pyplot as plt
    #import numpy as np
    from itertools import product, combinations
    fig = plt.figure(figsize=(20,10))
    ax = fig.gca(projection='3d')
    ax.set_aspect("equal")
    ax._axis3don = False
    

    



    #draw sphere
    R = 1
    u, v = np.mgrid[0:2*np.pi:50j, 0:np.pi:50j]
    x=R*np.cos(u)*np.sin(v)
    y=R*np.sin(u)*np.sin(v)
    z=R*np.cos(v)
    #ax.plot_surface(x, y, z, color="r", alpha = 0.15)

    ax.plot_surface(x, y, z, cmap=cm.YlGnBu_r,rstride=1, cstride=1, alpha = 0.10, linewidth = 0.15)
    ax.view_init(vpolar, vazim)
    #draw patch
    #u, v = np.mgrid[0:2*np.pi:50j, 0:(np.pi/7):50j]
    #x=R*np.cos(u)*np.sin(v)
    #y=R*np.sin(u)*np.sin(v)
    #z=R*np.cos(v)
    #ax.plot_surface(x, y, z, color="r", alpha = 0.25)
    
    
    
    #draw obstacles
    
    for p in lista_obstaculos:
        ax.scatter([p[0]],[p[1]],[p[2]], color="b", s=10, alpha = 0.2)
    
    #draw trajectory
    for p in trayectoria:
        ax.scatter([p[0]],[p[1]],[p[2]], color="k",s=20, alpha = 0.7)
    
    #Plot the x positive direction
    
    ax.quiver(1.5,0,0,1,0,0, length=0.5, arrow_length_ratio = .5)
    ax.quiver(0,1.5,0,0,1,0, length=0.5, arrow_length_ratio = .5)
    ax.quiver(0,0,1.5,0,0,1, length=0.5, arrow_length_ratio = .5)
    
    #fig.savefig('BS_24_Obs_test_01{}.png'.format(nombre(numero + 1)))
    #ax.view_init(80, 30)
    #plt.close()
    plt.show()

def obs_uniforme(N, R, size):
    
    list_obs = []
    omega = np.cos(size)
    while len(list_obs) < N:
        x, y, z = np.random.uniform(-1,1), np.random.uniform(-1,1), np.random.uniform(-1,1)
        v = np.array([x, y, z])
        norma = np.linalg.norm(v)
        if norma <= R:
            n = v/norma
            if not np.dot(n, np.array([0.,0.,1.]))/R > omega:
                list_obs.append(R*n)
    
    return list_obs    


def puntos_obs_j(r_omega, theta_omega, n):
    r , theta, phi = trans_c_s(r_omega[0],r_omega[1],r_omega[2])
    rp = rot_finita(r_omega, phi_uni(theta, phi), theta_omega)
    puntos_obs_j = [rp]
    for i in range(1,n):
        x = rot_finita(rp, r_omega, 2*np.pi/n)
        puntos_obs_j.append(x)
        rp = x
    return puntos_obs_j



def puntos_obs(lista_obstaculos, size):
    mis_obs = []
    for i in range(len(lista_obstaculos)):
        a = lista_obstaculos[i]
        b = size
        mis_obs = mis_obs + puntos_obs_j(a,b,100)
    return mis_obs
#Collision_check es una función que, dada una trayectoria: una lista de vectores que
#pasan por puntos sucesivos de la trayectoria, verifica si alguna de estas posiciones
#interesecto a alguno de los obstáculos. En caso de que así sea, actualiza conforme una
#colision elastica. En caso de no intersectar a ningun obstaculo regresa una lista
#con dos vectores: posicion inicial y posicion final en ese orden.

def penetrate_obs(lista_vect, lista_obs, size):
    metiches = []
    for obs in lista_obs:
        r_omega, theta_omega = obs, size
        #frontera = .2
        #metiches = []
        for v in lista_vect:
            tamanho = np.cos(theta_omega)
            if np.dot(v,r_omega) >= tamanho:
                #print 'Penetro el mother fucker obstacle'
                metiches.append(v)
                
            else:
                continue
    #print 'no choco el mother fucker'
    #valor = False
    return metiches
    

def check_collision(lista_vect, lista_obs, size):
    for obs in lista_obs:
        r_omega, theta_omega = obs, size 
        for v in lista_vect:
            tamanho = np.cos(theta_omega)
            if np.dot(v,r_omega) > tamanho:
                return  True
            else:
                continue
    return False
    

def vector_q(x,s):
    q = np.tan(s)
    return q*x

#Distribución en el polo sur

def polo_s(n, R):
    l = []
    for i in range(n):
        l.append(np.array([0,0,-R]))
    return l

#Dsitribución en el ecuador

def dist_ecuador(n):
    l = []
    for i in range(n):
        x, y, z = trans_s_c(1.,np.pi/2, np.random.uniform(0,2*np.pi))
        l.append(np.array([x,y,z]))
    return l

# %%
def tangent_space(x1,x2,xo):
    np_prima = np.cross(np.cross(xo, x1), x1)
    nor_p = np_prima/np.linalg.norm(np_prima)
    up_prima = np.cross(np.cross(x1, x2), x1)
    up = up_prima/np.linalg.norm(up_prima)
    tp_prima = np.cross(x1, nor_p)
    tp = tp_prima/np.linalg.norm(tp_prima)
    y = (np.dot(up,tp))*tp - (np.dot(up, nor_p))*nor_p
    v_rot_prima = np.cross(x1, y)
    v_rot = v_rot_prima/np.linalg.norm(v_rot_prima)
    return v_rot

# %%
def uniform_inside_omega(N, R, size):

    list_obs = []
    omega = np.cos(size)
    while len(list_obs) < N:
        x, y, z = np.random.uniform(-1,1), np.random.uniform(-1,1), np.random.uniform(-1,1)
        v = np.array([x, y, z])
        norma = np.linalg.norm(v)
        if norma <= R:
            n = v/norma
            if not np.dot(n, np.array([0.,0.,1.]))/R < omega:
                list_obs.append(R*n)
    
    return list_obs

# %% [markdown]
# # COLLISIONS OBSTACLES

# %%
def collision_check(Lv, Lo, size):
    if len(Lv) == 1:
        return Lv[0], Lv[0], 0
    
    elif len(Lv) == 2:
        sproduct = np.dot(Lv[0], Lv[1])
        if abs(sproduct) > 1:
            if sproduct < 0:
                sproduct = -1.
            else:
                sproduct = 1.
                
        alpha = np.arccos(sproduct)
        for obs in Lo:
            r_o = obs
            if np.dot(Lv[1],r_o) > np.cos(size):
                v_rot = tangent_space(Lv[0], Lv[1], r_o)
                x_final = rot_finita(Lv[1], -v_rot, alpha)
                return Lv[1], x_final, 0
    else:
        for k in range(1,len(Lv)):
            for obs in Lo:
                r_o = obs
                if np.dot(Lv[k],r_o) > np.cos(size):
                    v_rot = tangent_space(Lv[0], Lv[k], r_o)
                    
                    if k == len(Lv) - 1:
                        sproduct = np.dot(Lv[k-1], Lv[k])
                        if abs(sproduct) > 1:
                            if sproduct < 0:
                                sproduct = -1.
                        else:
                            sproduct = 1.
                        
                        
                    
                    else:
                        sproduct = np.dot(Lv[k], Lv[-1])
                        if abs(sproduct) > 1:
                            if sproduct < 0:
                                sproduct = -1.
                            else:
                                sproduct = 1.
                    alpha = np.arccos(sproduct)
                    
                    x_final = rot_finita(Lv[k], -v_rot, alpha)
                    return Lv[k], x_final, k
        return Lv[0], Lv[-1], 0

# %% [markdown]
# # EXTERNAL FIELDS

# %%
#Definimos las funciones para el campo exterior
#q = (R)*np.tan(s/(R))
def nuevo_r_field(r, vector_q, field):
    #nfield = np.tan(field)
    xf = np.linalg.norm(field)
    if xf == 0:
        nfield = 0
    else:
        fvecuni = field/xf
        nfield = np.tan(xf)*fvecuni
    #y = r + vector_q + nfield
    y = r + vector_q + nfield
    y = y/np.linalg.norm(y)
    return y

def field_theta(ri, v0):
    r, theta, phi = trans_c_s(ri[0],ri[1],ri[2])
    #(-2*v0*np.sin(2*theta)*theta_uni(theta, phi))
    #(-v0*np.sin(phi)*phi_uni(theta, phi))
    field = -v0*theta_uni(theta, phi) + ((v0 + theta)**2)*phi_uni(theta, phi)
    return field

def actualiza_field_theta(r,s,v0):
    v1, v2 = base_ort_nor(r)
    pre_q = vector_des(v1,v2)
    q = vector_q(pre_q, s)
    return nuevo_r_field(r, q, field_theta(r,v0))
    #return nuevo_r_field(r, pre_q, field_theta(r,v0))


def act_n_field(lista, v0):
    l = []
    for v in lista:
        s = ese(D,dt)
        l.append(actualiza_field_theta(v, s, v0))
    return l

# %%
def coeficiente(n,N):
    #N es el numero de pasos, por lo que el tiempo total transcurrido hasta ese momento es
    t = dt * N
    return ((2*n + 1.)/(4*np.pi)) * np.exp(-n*(n + 1)*D*t/R**2)

# %%
def distribucion(theta, N, orden):
    #lista = []
    c = np.zeros(orden)
    for n in range(orden):
        c[n] = coeficiente(n,N)
        #lista.append(coeficiente(n,N)*np.polynomial.legendre.legval(np.cos(theta), c))
    lista = np.polynomial.legendre.legval(np.cos(theta), c)
    #print lista
    #return sum(lista)
    return lista

# %%
def distribucion_weighted(theta, N, orden):
    #lista = []
    c = np.zeros(orden)
    for n in range(orden):
        c[n] = coeficiente(n,N)
        #lista.append(coeficiente(n,N)*np.polynomial.legendre.legval(np.cos(theta), c))
    lista = np.polynomial.legendre.legval(np.cos(theta), c)*np.sin(theta)*2*np.pi
    #print lista
    #return sum(lista)
    return lista

# %%
# %matplotlib inline

# %%
#D es el coeficiente de difusion, R el radio de la esfera y dt el tamaño del paso.
D = 1e-1
R = 1.
dt = np.log(2)*1e-3
theta = np.linspace(0.0,np.pi,1000)

for i in range(1,10):
    #fig = plt.figure()
    plt.rc('text', usetex = True)
    plt.fill_between(theta, distribucion_weighted(theta,280*i,1000) ,y2 = 0, color = '#778899', alpha = .16)
    #plt.title("t = {} pasos".format(i))
    plt.ylim(0, 2)
    plt.xlim(0,np.pi+0.01)
    plt.xlabel(r"$\theta$ " , fontsize = 15)
    plt.ylabel(r"$\displaystyle \sin{\theta} \sum^{500} \frac{2n + 1}{2}\exp{-[n(n+1)Dt/R^2]P_{n}(\cos{\theta})}$", fontsize = 14)
plt.show()
#plt.savefig('Chingona_Weighted_01.pdf', dpi = 600, bbox_inches = 'tight')

# %%
#plt.rc('text', usetex = True)
y = (1/(2.))*np.ones(len(theta))*np.sin(theta)

#plt.rc('text', usetex=True)
#plt.rc('font', family='serif')
plt.plot(theta, y, 'r', label = r'$\mbox{P}(\theta) = \frac{1}{2} \sin{\theta}$', alpha = 0.5)
plt.fill_between(theta, y ,y2 = 0, color = '#778899', alpha = .50)
plt.xlabel(r'$\theta$', fontsize = 15)
plt.ylabel(r'$\lim_{t \rightarrow \infty} P_{t}$', fontsize = 15)
plt.xlim(0,np.pi)
plt.ylim(0,2)
plt.legend(loc=1)
plt.show()

#plt.savefig('Chingona_Weighted_02.pdf', dpi = 600, bbox_inches = 'tight')

#plt.title(r'\displaystyle \lim_{t\rightarrow \infty} \sum_{i=0}^{\infty} #
#\frac{2n + 1}{4\pi}\exp{\left [-n(n + 1)Dt/R^2 \right]}P_{n}(\cos(\theta))')

# %% [markdown]
# # SIMULACIONES

# %%
# %pwd
# Out:
# '/Users/adrianovaldesgomez/Documents/Adriano_Programming'

# %%
# !mkdir Animacion_Free_Diff_01

# %%
# %ls
# Out:
# Adriano_Masters_Code_0416_01.py
# Analytic_vs_Numeric.ipynb
# Animacion_Free_Diff_01/
# AntiJoin.ipynb
# Bi_Stable_Field_Images0000.png
# Dpole_North_ini_dist_Hist_Phi_t.txt
# Dpole_North_ini_dist_Hist_Theta_t.txt
# Dpole_North_ini_dist_Mean_Theta_t.txt
# Dpole_North_ini_dist_Mean_phi_t.txt
# Dpole_North_ini_dist_Var_Phi_t.txt
# Dpole_North_ini_dist_Var_Theta_t.txt
# Julia_Tests.ipynb
# Normalied_Histograms.ipynb
# OBS_SIM_Test_01/
# Obstacles Intersection.ipynb
# Obstacles_Simulations_UB_Density_01.ipynb
# Playing fool Py3.ipynb
# Potentials.ipynb
# R_Anaconda_Environment_test.ipynb
# SHY42_Animation_01.avi
# Test_01.ipynb
# UnsuperviseLearning.ipynb
# Valdes_Sanders_2016.ipynb
# Y10.ipynb
# Y10_28_10_2017/
# Y20.ipynb
# Y20_Hist_Theta_t0.png
# Y20_Hist_Theta_tinfty.png
# Y30.ipynb
# Y30_29112017/
# Y30_Hist_Phi_t.txt
# Y30_Hist_Phi_t0.png
# Y30_Hist_Phi_tinfty.png
# Y30_Hist_Theta_t.txt
# Y30_Hist_Theta_t0.png
# Y30_Hist_Theta_t2.txt
# Y30_Hist_Theta_tinfty.png
# Y30_Mean_Theta_t.txt
# Y30_Mean_Theta_t2.txt
# Y30_Mean_phi_t.txt
# Y30_Var_Phi_t.txt
# Y30_Var_Theta_t.txt
# Y30_Var_Theta_t2.txt
# modfiles.txt

# %%
# %cd Animacion_Free_Diff_01/
# Out:
# /Users/adrianovaldesgomez/Documents/Adriano_Programming/Animacion_Free_Diff_01

# %% [markdown]
# ## Backbone

# %%
D = 1e-1
dt = np.log(2)*1e-1
#v0 = 2.5*np.sqrt(2*D)*dt
#dist_uni = obs_uniforme(800, 1., 0)
dist_ini = polo_n(600,1.)
plot_particles(dist_ini,0, 0, 0)
rs = dist_uni
for i in range(2000):
         
        nuevas_pos = act_n(rs, v0,dt)
        plot_particles(nuevas_pos, 0, 0, i + 1)
        rs = nuevas_pos

# %%
# !mencoder "mf://*.png" -o Sim_free_diff_01.avi -ovc lavc -lavcopts vcodec=msmpeg4v2:autoaspect:vbitrate=2160000:mbd=2:keyint=132:vqblur=1.0:cmp=2:subcmp=2:dia=2:o=mpv_flags=+mv0:last_pred=3 -fps 15
# Out:
# MEncoder 1.3.0-4.2.1 (C) 2000-2016 MPlayer Team
# 224 audio & 451 video codecs
# success: format: 16  data: 0x0 - 0x0
# MF file format detected.
# [mf] search expr: *.png
# [mf] number of files: 2001 (16008)
# [demux_mf] file type was not set! trying 'type=png'...
# VIDEO:  [MPNG]  0x0  24bpp  25.000 fps    0.0 kbps ( 0.0 kbyte/s)
# [V] filefmt:16  fourcc:0x474E504D  size:0x0  fps:25.000  ftime:=0.0400
# Input fps will be interpreted as 15.000 instead.
# libavcodec version 57.24.102 (internal)
# Opening video filter: [expand osd=1]
# Expand: -1 x -1, -1 ; -1, osd: 1, aspect: 0.000000, round: 1
# ==========================================================================
# Opening video decoder: [ffmpeg] FFmpeg's libavcodec codec family
# Selected video codec: [ffpng] vfm: ffmpeg (FFmpeg PNG)
# ==========================================================================
# Could not find matching colorspace - retrying with -vf scale...
# Opening video filter: [scale]
# Movie-Aspect is undefined - no prescaling applied.
# [swscaler @ 0x1095ee410]bicubic scaler, from rgba to yuv420p using MMXEXT
# videocodec: libavcodec (576x576 fourcc=3234504d [MP42])
# [VE_LAVC] High quality encoding selected (non-realtime)!
# Movie-Aspect is 1.00:1 - prescaling to correct movie aspect.
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Writing header...
# ODML: vprp aspect is 16384:16384.
# Writing header...
# ODML: vprp aspect is 16384:16384.
# Pos:   0.1s      1f ( 0%)  0.00fps Trem:   0min   0mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos:   0.1s      2f ( 0%)  0.00fps Trem:   0min   0mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos:   0.2s      3f ( 0%)  0.00fps Trem:   0min   9mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos:   0.3s      4f ( 0%)  0.00fps Trem:   0min   6mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos:   0.3s      5f ( 0%)  0.00fps Trem:   0min   4mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos:   0.4s      6f ( 0%)  0.00fps Trem:   0min   3mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos:   0.5s      7f ( 0%)  0.00fps Trem:   0min   3mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos:   0.5s      8f ( 0%)  0.00fps Trem:   0min   2mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos:   0.6s      9f ( 0%)  0.00fps Trem:   0min   2mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos:   0.7s     10f ( 0%)  0.00fps Trem:   0min   2mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos:   0.7s     11f ( 0%)  0.00fps Trem:   0min   2mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos:   0.8s     12f ( 0%)  0.00fps Trem:   0min   2mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos:   0.9s     13f ( 0%)  0.00fps Trem:   0min   2mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos:   0.9s     14f ( 0%)  0.00fps Trem:   0min   1mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos:   1.0s     15f ( 0%)  0.00fps Trem:   0min   1mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos:   1.1s     16f ( 0%)  0.00fps Trem:   0min   1mb  A-V:0.000 [70:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos:   1.1s     17f ( 0%)  0.00fps Trem:   0min   1mb  A-V:0.000 [69:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos:   1.2s     18f ( 0%)  0.00fps Trem:   0min   1mb  A-V:0.000 [67:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos:   1.3s     19f ( 0%)  0.00fps Trem:   0min   1mb  A-V:0.000 [66:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos:   1.3s     20f ( 0%)  0.00fps Trem:   0min   1mb  A-V:0.000 [65:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos:   1.4s     21f ( 1%)  0.00fps Trem:   0min   1mb  A-V:0.000 [64:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos:   1.5s     22f ( 1%)  0.00fps Trem:   0min   1mb  A-V:0.000 [63:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos:   1.5s     23f ( 1%)  0.00fps Trem:   0min   1mb  A-V:0.000 [63:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos:   1.6s     24f ( 1%)  0.00fps Trem:   0min   1mb  A-V:0.000 [62:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos:   1.7s     25f ( 1%)  0.00fps Trem:   0min   1mb  A-V:0.000 [61:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos:   1.7s     26f ( 1%)  0.00fps Trem:   0min   1mb  A-V:0.000 [61:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos:   1.8s     27f ( 1%)  0.00fps Trem:   0min   1mb  A-V:0.000 [60:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos:   1.9s     28f ( 1%)  0.00fps Trem:   0min   1mb  A-V:0.000 [59:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos:   1.9s     29f ( 1%)  0.00fps Trem:   0min   1mb  A-V:0.000 [59:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos:   2.0s     30f ( 1%)  0.00fps Trem:   0min   1mb  A-V:0.000 [58:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos:   2.1s     31f ( 1%)  0.00fps Trem:   0min   1mb  A-V:0.000 [58:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos:   2.1s     32f ( 1%)  0.00fps Trem:   0min   1mb  A-V:0.000 [58:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos:   2.2s     33f ( 1%)  0.00fps Trem:   0min   1mb  A-V:0.000 [58:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos:   2.3s     34f ( 1%)  0.00fps Trem:   0min   1mb  A-V:0.000 [57:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos:   2.3s     35f ( 1%)  0.00fps Trem:   0min   1mb  A-V:0.000 [57:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos:
0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos: 132.1s   1981f (99%) 71.01fps Trem:   0min   7mb  A-V:0.000 [456:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos: 132.1s   1982f (99%) 71.01fps Trem:   0min   7mb  A-V:0.000 [457:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos: 132.2s   1983f (99%) 71.01fps Trem:   0min   7mb  A-V:0.000 [457:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos: 132.3s   1984f (99%) 71.01fps Trem:   0min   7mb  A-V:0.000 [457:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos: 132.3s   1985f (99%) 71.01fps Trem:   0min   7mb  A-V:0.000 [457:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos: 132.4s   1986f (99%) 71.01fps Trem:   0min   7mb  A-V:0.000 [457:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos: 132.5s   1987f (99%) 71.01fps Trem:   0min   7mb  A-V:0.000 [457:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos: 132.5s   1988f (99%) 71.01fps Trem:   0min   7mb  A-V:0.000 [458:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos: 132.6s   1989f (99%) 71.01fps Trem:   0min   7mb  A-V:0.000 [458:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos: 132.7s   1990f (99%) 71.01fps Trem:   0min   7mb  A-V:0.000 [458:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos: 132.7s   1991f (99%) 71.01fps Trem:   0min   7mb  A-V:0.000 [458:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos: 132.8s   1992f (99%) 71.01fps Trem:   0min   7mb  A-V:0.000 [458:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos: 132.9s   1993f (99%) 71.00fps Trem:   0min   7mb  A-V:0.000 [458:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos: 132.9s   1994f (99%) 71.00fps Trem:   0min   7mb  A-V:0.000 [459:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos: 133.0s   1995f (99%) 71.00fps Trem:   0min   7mb  A-V:0.000 [459:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos: 133.1s   1996f (99%) 71.01fps Trem:   0min   7mb  A-V:0.000 [459:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos: 133.1s   1997f (99%) 70.99fps Trem:   0min   7mb  A-V:0.000 [459:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos: 133.2s   1998f (99%) 70.99fps Trem:   0min   7mb  A-V:0.000 [459:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos: 133.3s   1999f (99%) 70.99fps Trem:   0min   7mb  A-V:0.000 [460:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos: 133.3s   2000f (99%) 70.99fps Trem:   0min   7mb  A-V:0.000 [460:0]
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x1095d4fe0]AVFrame.width or height is not set
# Pos: 133.4s   2001f (100%) 70.99fps Trem:   0min   7mb  A-V:0.000 [460:0]
#
# Skipping frame!
# Pos: 133.4s   2002f (100%) 71.02fps Trem:   0min   7mb  A-V:0.000 [460:0]
#
# Flushing video frames.
# Writing index...
# Writing header...
# ODML: vprp aspect is 16384:16384.
#
# Video stream:  460.378 kbit/s  (57547 B/s)  size: 7676801 bytes  133.400 secs  2002 frames

# %%
[0 for i in range(3)]
# Out:
# [0, 0, 0]

# %% [markdown]
# ### Función para thetas

# %%
def obt_thetas(lista):
    lista_thetas = []
    for elemento in lista:
        r,theta, phi = trans_c_s(elemento[0],elemento[1],elemento[2])
        lista_thetas.append(theta)
    return lista_thetas

# %%
import time

# %%
# %pwd
# Out:
# '/Users/adrianovaldesgomez/Documents/Adriano_Programming/Animacion_Free_Diff_01'

# %%
# %cd ..
# Out:
# /Users/adrianovaldesgomez/Documents/Adriano_Programming

# %%
# %mkdir AnalyticNumeric_theta_t

# %%
# %cd AnalyticNumeric_theta_t/
# Out:
# [Errno 2] No such file or directory: 'AnalyticNumeric_theta_t/'
# /Users/adrianovaldesgomez/Documents/Adriano_Programming/Animacion_Free_Diff_01

# %%
start_time = time.time()
D = 1*1e-1
dt = 1*np.log(2)*1e-3
#dist_ini = polo_n(10000,1.)
#rs = dist_ini
#thetas = [[0 for i in range(10000)]]
for i in range(5000):
    nuevas_pos = act_n(rs,D,dt)
    thetas.append(obt_thetas(nuevas_pos))
    rs = nuevas_pos
np.savetxt("Sim_Thetas_t_02.txt", thetas)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 13914.976339101791 seconds ---

# %%
start_time = time.time()
#D = 1*1e-1
#dt = 1*np.log(2)*1e-3
#dist_ini = polo_n(10000,1.)
#rs = dist_ini
#thetas = [[0 for i in range(10000)]]
for i in range(5000):
    nuevas_pos = act_n(rs,D,dt)
    thetas.append(obt_thetas(nuevas_pos))
    rs = nuevas_pos
np.savetxt("Sim_Thetas_t_03_extencion.txt", thetas)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 20038.207894086838 seconds ---

# %%
10000./3600
# Out:
# 2.7777777777777777

# %%
import numpy as np

# %%
thetas = np.loadtxt("Sim_Thetas_t_03_extencion.txt")

# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
type(thetas)
# Out:
# numpy.ndarray

# %%
max(thetas[1])
# Out:
# 0.07282578588794164

# %%
min(thetas[1])
# Out:
# 5.599348016994053e-07

# %%
plt.hist(thetas[15000], bins=50, normed=True);
plt.ylim(-.5,3);
# Out:
# /Users/adrianovaldesgomez/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
D = 1*1e-1
dt = 1*np.log(2)*1e-3
theta = np.linspace(0.0,np.pi,1000)

# %%
def Num_Analytic(n):
    fig = plt.figure(figsize=(7,5))
    plt.hist(thetas[n], bins=120, normed=True, color='cadetblue', alpha=0.95, label='Numeric Solution',#
             edgecolor='black', linewidth=.35);
    plt.plot(theta, distribucion_weighted(theta,n,1000), color = 'r', alpha = .6,#
             label=r"$P(\theta,t|0,0) = \sum P_{l}(\cos{\theta})\, \exp{[-l(l+1)D\,t/R]}$")
    plt.ylim(0,2.5);
    plt.xlim(0, np.pi);
    plt.legend(fontsize=14.0);
    plt.title("t = {0:.4f} s".format(n*dt), fontsize=14)
    plt.xlabel(r"$\theta$", fontsize=15)
    fig.savefig('Sim_free_diff_analytic_vs_Numeric_Img{}.png'.format(nombre(n)), dpi=200)

# %%
len(thetas)
# Out:
# 20001

# %%
# %pwd
# Out:
# '/Users/adrianovaldesgomez/Documents/Adriano_Programming/AnalyticNumeric_theta_t'

# %%
# %cd ..
# Out:
# /Users/adrianovaldesgomez/Documents/Adriano_Programming

# %%
# %mkdir Analytic_vs_Numeric_Snapshots_Paper

# %%
# %cd Analytic_vs_Numeric_Snapshots_Paper/
# Out:
# /Users/adrianovaldesgomez/Documents/Adriano_Programming/Analytic_vs_Numeric_Snapshots_Paper

# %%
Num_Analytic(thetas.shape[0]-1)
# Out:
# /Users/adrianovaldesgomez/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
tick_labels
# Out:
# ['0.0',
#  '0.5235987755982988',
#  '1.0471975511965976',
#  '1.5707963267948966',
#  '2.0943951023931953',
#  '2.6179938779914944',
#  '3.141592653589793']

# %%
import fractions

# %%
str(fractions.Fraction(np.pi,3))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-126-d634d57ddf91> in <module>()
# ----> 1 str(fractions.Fraction(np.pi,3))
#
# /Users/adrianovaldesgomez/anaconda/envs/py35/lib/python3.5/fractions.py in __new__(cls, numerator, denominator, _normalize)
#     180                 )
#     181         else:
# --> 182             raise TypeError("both arguments should be "
#     183                             "Rational instances")
#     184
#
# TypeError: both arguments should be Rational instances

# %% [markdown]
# ## Other approaches for comparision

# %%
mean_thetas_t =[]
for ensamble in thetas:
    mean_thetas_t.append(np.mean(ensamble))

# %%
mean_thetas_square_t = []
for ensamble in thetas:
    mean_thetas_square_t.append(np.var(ensamble))

# %%
tiempos = []
suma = 0.
for i in range(thetas.shape[0]):
    suma =+ i*dt
    tiempos.append(suma)

# %%
tiempos2 = []
suma = 0.
for i in range(len(theta_num_mean_t)):
    suma =+ i*dt
    tiempos2.append(suma)

# %%
# !pwd
# Out:
# /Users/adrianovaldesgomez/Documents/Adriano_Programming/AnalyticNumeric_theta_t

# %%
plt.plot(tiempos, mean_thetas_t, label= 'Numeric Simulation')
#plt.plot(tiempos, np.arccos(np.exp(-(2*D*np.array(tiempos)))), label='Analytic')
plt.plot(tiempos2, theta_numint_mean_t, label='Analytical Numerical Int')
plt.plot(tiempos2, np.pi/2*np.ones_like(tiempos2), label=r'$\pi/2$')
plt.legend(fontsize=13)
plt.xlabel(r"$t$", fontsize=15)
plt.ylabel(r"$\langle \theta(t) \rangle$", fontsize=15)
plt.savefig("Mean_of_theta_t_Num_Ana.png", dpi=200)

# %%
var = (np.pi**2 - 4)/2. - np.pi**2/4

# %%
var
# Out:
# 0.4674011002723395

# %% [markdown]
# ## Expresión tiempos cortos

# %%
s2 = 4*D*np.array(tiempos) 
s5 = 4*D*np.array(tiempos) - (4/3.)*D*np.array(tiempos)**2
s6 = 4*D*np.array(tiempos) - (4/3.)*D*np.array(tiempos)**2 - (8/45.)*D*np.array(tiempos)**3
s7 = 4*D*np.array(tiempos) - 3.2*D*np.array(tiempos)

# %%
s3 = 1.6/2*D*np.array(tiempos)

# %% [markdown]
# ## Expresión tiempos largos

# %%
s4 = ((np.pi**2 - 4)/2)*(1 -((3*np.pi**2)/(4*np.pi**2-16))*np.exp(-2*D*np.array(tiempos)) ) - (np.pi**2/4.)

# %%
D
# Out:
# 0.1

# %%
# !pwd
# Out:
# /Users/adrianovaldesgomez/Documents/Adriano_Programming/AnalyticNumeric_theta_t

# %%
plt.plot(tiempos[:], mean_thetas_square_t[:], label= 'Numeric')
#plt.plot(tiempos[:2000], s2[:2000], label= 'Analictical Short time Sol.', linestyle='--')
#plt.plot(tiempos[:9000], s3[:9000], label= 'Fitted linear Short time', linestyle='--')
#plt.plot(tiempos[:2000], s4[:2000], label= 'Short time', linestyle='--')
#plt.plot(tiempos[:2000], s5[:2000], label= 'Short time', linestyle='--')
#plt.plot(tiempos[-9000:], s4[-9000:], label= 'Short time', linestyle='--')
#plt.plot(tiempos[:9000], s7[:9000], label= 'Correct Variance', linestyle='--')
plt.plot(tiempos, var*np.ones(len(tiempos)), label= r'$\sigma^2(\infty)$')

plt.plot(tiempos2, theta_num_mean_t, label = 'Numerical Integration')


#plt.plot(tiempos, np.arccos(np.exp(-(2*D*np.array(tiempos)))), label='Analytic')
plt.legend(fontsize=13)
plt.xlabel(r"$t$", fontsize=15)
plt.ylabel(r"$\langle \theta(t)^2 \rangle - \langle \theta(t) \rangle^2$", fontsize=15);
plt.xlim(0,15)
#plt.ylim(0,0.000000000000000000000000001);
plt.savefig("Sigma_Square_t_Num_Ana.png", dpi=200)

# %%
mean_cos_thetas_t =[]
for ensamble in thetas:
    ensamble = np.array(ensamble)
    cos_ens = np.cos(ensamble)
    mean_cos_thetas_t.append(np.mean(cos_ens))

# %%
plt.plot(tiempos, mean_cos_thetas_t, label= 'Numeric')
plt.plot(tiempos, np.exp(-(2*D*np.array(tiempos))), label='Analytic')
plt.legend(fontsize=13)
plt.xlabel(r"$t$", fontsize=15)
plt.ylabel(r"$\langle \cos{[\theta(t)]} \rangle$", fontsize=15)
plt.savefig("Mean_of_cos_theta_t_Num_Ana.png", dpi=200)

# %%
plt.plot(tiempos, np.cos(np.array(mean_thetas_t)), label= 'Numeric')
plt.plot(tiempos, np.exp(-(1.7*D*np.array(tiempos))), label='Analytic')
plt.legend(fontsize=13)

# %% [markdown]
# ## Animation of free diffusion Analytic vs Numeric

# %%
# %pwd
# Out:
# '/Users/adrianovaldesgomez/Documents/Adriano_Programming'

# %%
# %cd ..
# Out:
# /Users/adrianovaldesgomez/Documents/Adriano_Programming

# %%
# !mkdir Sim_Analytic_vs_Numeric_free_diff

# %%
# %cd Sim_Analytic_vs_Numeric_free_diff/
# Out:
# /Users/adrianovaldesgomez/Documents/Adriano_Programming/Sim_Analytic_vs_Numeric_free_diff

# %%
for n in range(0,1000):
    Num_Analytic(n+1)
# Out:
# /Users/adrianovaldesgomez/anaconda/envs/py35/lib/python3.5/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-91-a99733d75cdc> in <module>()
#       1 for n in range(0,1000):
# ----> 2     Num_Analytic(n+1)
#
# <ipython-input-89-c1af700f45a2> in Num_Analytic(n)
#       8     plt.legend();
#       9     plt.title("Time = {0:.4f} seg".format(n*dt, format_spec='.4'))
# ---> 10     fig.savefig('Sim_free_diff_analytic_vs_Numeric_Img{}.png'.format(nombre(n)), dpi=100)
#
# /Users/adrianovaldesgomez/anaconda/envs/py35/lib/python3.5/site-packages/matplotlib/figure.py in savefig(self, *args, **kwargs)
#    1571             self.set_frameon(frameon)
#    1572
# -> 1573         self.canvas.print_figure(*args, **kwargs)
#    1574
#    1575         if frameon:
#
# /Users/adrianovaldesgomez/anaconda/envs/py35/lib/python3.5/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2250                 orientation=orientation,
#    2251                 bbox_inches_restore=_bbox_inches_restore,
# -> 2252                 **kwargs)
#    2253         finally:
#    2254             if bbox_inches and restore_bbox:
#
# /Users/adrianovaldesgomez/anaconda/envs/py35/lib/python3.5/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     543
#     544     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 545         FigureCanvasAgg.draw(self)
#     546         renderer = self.get_renderer()
#     547         original_dpi = renderer.dpi
#
# /Users/adrianovaldesgomez/anaconda/envs/py35/lib/python3.5/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     462
#     463         try:
# --> 464             self.figure.draw(self.renderer)
#     465         finally:
#     466             RendererAgg.lock.release()
#
# /Users/adrianovaldesgomez/anaconda/envs/py35/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# /Users/adrianovaldesgomez/anaconda/envs/py35/lib/python3.5/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1142
#    1143             mimage._draw_list_compositing_images(
# -> 1144                 renderer, self, dsu, self.suppressComposite)
#    1145
#    1146             renderer.close_group('figure')
#
# /Users/adrianovaldesgomez/anaconda/envs/py35/lib/python3.5/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, dsu, suppress_composite)
#     137     if not_composite or not has_images:
#     138         for zorder, a in dsu:
# --> 139             a.draw(renderer)
#     140     else:
#     141         # Composite any adjacent images together
#
# /Users/adrianovaldesgomez/anaconda/envs/py35/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# /Users/adrianovaldesgomez/anaconda/envs/py35/lib/python3.5/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2424             renderer.stop_rasterizing()
#    2425
# -> 2426         mimage._draw_list_compositing_images(renderer, self, dsu)
#    2427
#    2428         renderer.close_group('axes')
#
# /Users/adrianovaldesgomez/anaconda/envs/py35/lib/python3.5/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, dsu, suppress_composite)
#     137     if not_composite or not has_images:
#     138         for zorder, a in dsu:
# --> 139             a.draw(renderer)
#     140     else:
#     141         # Composite any adjacent images together
#
# /Users/adrianovaldesgomez/anaconda/envs/py35/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# /Users/adrianovaldesgomez/anaconda/envs/py35/lib/python3.5/site-packages/matplotlib/text.py in draw(self, renderer)
#     800                     textrenderer.draw_text(gc, x, y, clean_line,
#     801                                            textobj._fontproperties, angle,
# --> 802                                            ismath=ismath, mtext=mtext)
#     803
#     804         gc.restore()
#
# /Users/adrianovaldesgomez/anaconda/envs/py35/lib/python3.5/contextlib.py in __exit__(self, type, value, traceback)
#      75                 value = type()
#      76             try:
# ---> 77                 self.gen.throw(type, value, traceback)
#      78                 raise RuntimeError("generator didn't stop after throw()")
#      79             except StopIteration as exc:
#
# /Users/adrianovaldesgomez/anaconda/envs/py35/lib/python3.5/site-packages/matplotlib/text.py in _wrap_text(textobj)
#      58             textobj.set_text(old_text)
#      59     else:
# ---> 60         yield textobj
#      61
#      62
#
# /Users/adrianovaldesgomez/anaconda/envs/py35/lib/python3.5/site-packages/matplotlib/text.py in draw(self, renderer)
#     752
#     753         with _wrap_text(self) as textobj:
# --> 754             bbox, info, descent = textobj._get_layout(renderer)
#     755             trans = textobj.get_transform()
#     756
#
# /Users/adrianovaldesgomez/anaconda/envs/py35/lib/python3.5/site-packages/matplotlib/text.py in _get_layout(self, renderer)
#     360                 w, h, d = renderer.get_text_width_height_descent(clean_line,
#     361                                                         self._fontproperties,
# --> 362                                                         ismath=ismath)
#     363             else:
#     364                 w, h, d = 0, 0, 0
#
# /Users/adrianovaldesgomez/anaconda/envs/py35/lib/python3.5/site-packages/matplotlib/backends/backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     228             fontsize = prop.get_size_in_points()
#     229             w, h, d = texmanager.get_text_width_height_descent(s, fontsize,
# --> 230                                                                renderer=self)
#     231             return w, h, d
#     232
#
# /Users/adrianovaldesgomez/anaconda/envs/py35/lib/python3.5/site-packages/matplotlib/texmanager.py in get_text_width_height_descent(self, tex, fontsize, renderer)
#     674         else:
#     675             # use dviread. It sometimes returns a wrong descent.
# --> 676             dvifile = self.make_dvi(tex, fontsize)
#     677             dvi = dviread.Dvi(dvifile, 72 * dpi_fraction)
#     678             try:
#
# /Users/adrianovaldesgomez/anaconda/envs/py35/lib/python3.5/site-packages/matplotlib/texmanager.py in make_dvi(self, tex, fontsize)
#     421                      'string:\n%s\nHere is the full report generated by '
#     422                      'LaTeX: \n\n' % repr(tex.encode('unicode_escape')) +
# --> 423                      report))
#     424             else:
#     425                 mpl.verbose.report(report, 'debug')
#
# RuntimeError: LaTeX was not able to process the following string:
# b'Time = 48.5896 seg'
# Here is the full report generated by LaTeX:

# %%
# !mencoder "mf://*.png" -o Sim_free_diff_NumvsAnalytic_01.avi -ovc lavc -lavcopts vcodec=msmpeg4v2:autoaspect:vbitrate=2160000:mbd=2:keyint=132:vqblur=1.0:cmp=2:subcmp=2:dia=2:o=mpv_flags=+mv0:last_pred=3 -fps 3
# Out:
# MEncoder 1.3.0-4.2.1 (C) 2000-2016 MPlayer Team
# 224 audio & 451 video codecs
# success: format: 16  data: 0x0 - 0x0
# MF file format detected.
# [mf] search expr: *.png
# [mf] number of files: 700 (5600)
# [demux_mf] file type was not set! trying 'type=png'...
# VIDEO:  [MPNG]  0x0  24bpp  25.000 fps    0.0 kbps ( 0.0 kbyte/s)
# [V] filefmt:16  fourcc:0x474E504D  size:0x0  fps:25.000  ftime:=0.0400
# Input fps will be interpreted as 3.000 instead.
# libavcodec version 57.24.102 (internal)
# Opening video filter: [expand osd=1]
# Expand: -1 x -1, -1 ; -1, osd: 1, aspect: 0.000000, round: 1
# ==========================================================================
# Opening video decoder: [ffmpeg] FFmpeg's libavcodec codec family
# Selected video codec: [ffpng] vfm: ffmpeg (FFmpeg PNG)
# ==========================================================================
# Could not find matching colorspace - retrying with -vf scale...
# Opening video filter: [scale]
# Movie-Aspect is undefined - no prescaling applied.
# [swscaler @ 0x104006410]bicubic scaler, from rgba to yuv420p using MMXEXT
# videocodec: libavcodec (700x500 fourcc=3234504d [MP42])
# [VE_LAVC] High quality encoding selected (non-realtime)!
# Movie-Aspect is 1.40:1 - prescaling to correct movie aspect.
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Writing header...
# ODML: vprp aspect is 16384:11702.
# Writing header...
# ODML: vprp aspect is 16384:11702.
# Pos:   0.3s      1f ( 0%)  0.00fps Trem:   0min   0mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:   0.7s      2f ( 0%)  0.00fps Trem:   0min   0mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:   1.0s      3f ( 0%)  0.00fps Trem:   0min   0mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:   1.3s      4f ( 0%)  0.00fps Trem:   0min   0mb  A-V:0.000 [329:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:   1.7s      5f ( 0%)  0.00fps Trem:   0min   0mb  A-V:0.000 [320:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:   2.0s      6f ( 0%)  0.00fps Trem:   0min   0mb  A-V:0.000 [314:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:   2.3s      7f ( 1%)  0.00fps Trem:   0min   8mb  A-V:0.000 [307:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:
ps Trem:   0min   7mb  A-V:0.000 [276:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  38.7s    116f (16%) 52.68fps Trem:   0min   7mb  A-V:0.000 [276:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  39.0s    117f (16%) 52.70fps Trem:   0min   8mb  A-V:0.000 [276:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  39.3s    118f (16%) 52.75fps Trem:   0min   8mb  A-V:0.000 [276:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  39.7s    119f (17%) 52.87fps Trem:   0min   7mb  A-V:0.000 [276:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  40.0s    120f (17%) 52.96fps Trem:   0min   7mb  A-V:0.000 [276:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  40.3s    121f (17%) 53.02fps Trem:   0min   7mb  A-V:0.000 [275:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  40.7s    122f (17%) 53.00fps Trem:   0min   7mb  A-V:0.000 [275:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  41.0s    123f (17%) 53.04fps Trem:   0min   7mb  A-V:0.000 [275:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  41.3s    124f (17%) 53.13fps Trem:   0min   8mb  A-V:0.000 [275:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  41.7s    125f (17%) 53.21fps Trem:   0min   8mb  A-V:0.000 [275:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  42.0s    126f (18%) 53.30fps Trem:   0min   7mb  A-V:0.000 [275:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  42.3s    127f (18%) 53.32fps Trem:   0min   7mb  A-V:0.000 [275:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  42.7s    128f (18%) 53.42fps Trem:   0min   7mb  A-V:0.000 [275:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  43.0s    129f (18%) 53.53fps Trem:   0min   7mb  A-V:0.000 [275:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  43.3s    130f (18%) 53.61fps Trem:   0min   7mb  A-V:0.000 [275:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  43.7s    131f (18%) 53.67fps Trem:   0min   7mb  A-V:0.000 [275:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  44.0s    132f (18%) 53.68fps Trem:   0min   8mb  A-V:0.000 [275:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  44.3s    133f (19%) 53.82fps Trem:   0min   7mb  A-V:0.000 [278:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  44.7s    134f (19%) 53.90fps Trem:   0min   7mb  A-V:0.000 [278:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  45.0s    135f (19%) 53.98fps Trem:   0min   7mb  A-V:0.000 [278:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  45.3s    136f (19%) 54.10fps Trem:   0min   7mb  A-V:0.000 [278:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  45.7s    137f (19%) 54.11fps Trem:   0min   8mb  A-V:0.000 [278:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  46.0s    138f (19%) 54.18fps Trem:   0min   8mb  A-V:0.000 [278:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  46.3s    139f (19%) 54.25fps Trem:   0min   8mb  A-V:0.000 [278:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  46.7s    140f (20%) 54.35fps Trem:   0min   7mb  A-V:0.000 [278:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  47.0s    141f (20%) 54.42fps Trem:   0min   7mb  A-V:0.000 [278:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  47.3s    142f (20%) 54.49fps Trem:   0min   7mb  A-V:0.000 [277:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  47.7s    143f (20%) 54.54fps Trem:   0min   7mb  A-V:0.000 [277:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  48.0s    144f (20%) 54.55fps Trem:   0min   7mb  A-V:0.000 [277:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  48.3s    145f (20%) 54.57fps Trem:   0min   8mb  A-V:0.000 [277:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  48.7s    146f (20%) 54.64fps Trem:   0min   8mb  A-V:0.000 [277:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  49.0s    147f (21%) 54.73fps Trem:   0min   7mb  A-V:0.000 [277:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  49.3s    148f (21%) 54.71fps Trem:   0min   7mb  A-V:0.000 [277:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  49.7s    149f (21%) 54.78fps Trem:   0min   7mb  A-V:0.000 [277:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  50.0s    150f (21%) 54.84fps Trem:   0min   7mb  A-V:0.000 [277:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  50.3s    151f (21%) 54.91fps Trem:   0min   7mb  A-V:0.000 [276:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  50.7s    152f (21%) 54.93fps Trem:   0min   7mb  A-V:0.000 [276:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  51.0s    153f (21%) 54.98fps Trem:   0min   8mb  A-V:0.000 [277:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  51.3s    154f (22%) 55.02fps Trem:   0min   7mb  A-V:0.000 [276:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  51.7s    155f (22%) 55.10fps Trem:   0min   7mb  A-V:0.000 [276:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  52.0s    156f (22%) 55.18fps Trem:   0min   7mb  A-V:0.000 [276:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  52.3s    157f (22%) 55.18fps Trem:   0min   7mb  A-V:0.000 [276:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  52.7s    158f (22%) 55.24fps Trem:   0min   7mb  A-V:0.000 [276:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  53.0s    159f (22%) 55.32fps Trem:   0min   7mb  A-V:0.000 [276:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  53.3s    160f (22%) 55.40fps Trem:   0min   8mb  A-V:0.000 [276:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  53.7s    161f (23%) 55.44fps Trem:   0min   7mb  A-V:0.000 [276:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  54.0s    162f (23%) 55.46fps Trem:   0min   7mb  A-V:0.000 [276:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  54.3s    163f (23%) 55.52fps Trem:   0min   7mb  A-V:0.000 [275:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  54.7s    164f (23%) 55.61fps Trem:   0min   7mb  A-V:0.000 [275:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  55.0s    165f (23%) 55.67fps Trem:   0min   7mb  A-V:0.000 [275:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  55.3s    166f (23%) 55.74fps Trem:   0min   7mb  A-V:0.000 [275:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  55.7s    167f (23%) 55.82fps Trem:   0min   7mb  A-V:0.000 [275:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  56.0s    168f (24%) 55.87fps Trem:   0min   7mb  A-V:0.000 [275:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  56.3s    169f (24%) 55.94fps Trem:   0min   7mb  A-V:0.000 [275:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  56.7s    170f (24%) 55.92fps Trem:   0min   7mb  A-V:0.000 [275:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:  57.0s    171f (24%) 55.97fps Trem:   0min   7mb  A-V:0.000 [275:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos:
ps Trem:   0min   7mb  A-V:0.000 [268:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 213.3s    640f (91%) 61.37fps Trem:   0min   7mb  A-V:0.000 [268:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 213.7s    641f (91%) 61.39fps Trem:   0min   7mb  A-V:0.000 [268:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 214.0s    642f (91%) 61.40fps Trem:   0min   7mb  A-V:0.000 [268:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 214.3s    643f (91%) 61.41fps Trem:   0min   7mb  A-V:0.000 [268:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 214.7s    644f (92%) 61.42fps Trem:   0min   7mb  A-V:0.000 [268:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 215.0s    645f (92%) 61.40fps Trem:   0min   7mb  A-V:0.000 [268:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 215.3s    646f (92%) 61.41fps Trem:   0min   7mb  A-V:0.000 [268:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 215.7s    647f (92%) 61.42fps Trem:   0min   7mb  A-V:0.000 [268:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 216.0s    648f (92%) 61.44fps Trem:   0min   7mb  A-V:0.000 [268:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 216.3s    649f (92%) 61.45fps Trem:   0min   7mb  A-V:0.000 [268:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 216.7s    650f (92%) 61.47fps Trem:   0min   7mb  A-V:0.000 [268:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 217.0s    651f (93%) 61.45fps Trem:   0min   7mb  A-V:0.000 [268:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 217.3s    652f (93%) 61.45fps Trem:   0min   7mb  A-V:0.000 [268:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 217.7s    653f (93%) 61.44fps Trem:   0min   7mb  A-V:0.000 [268:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 218.0s    654f (93%) 61.45fps Trem:   0min   7mb  A-V:0.000 [268:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 218.3s    655f (93%) 61.46fps Trem:   0min   7mb  A-V:0.000 [268:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 218.7s    656f (93%) 61.45fps Trem:   0min   7mb  A-V:0.000 [268:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 219.0s    657f (93%) 61.47fps Trem:   0min   7mb  A-V:0.000 [268:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 219.3s    658f (94%) 61.47fps Trem:   0min   7mb  A-V:0.000 [268:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 219.7s    659f (94%) 61.49fps Trem:   0min   7mb  A-V:0.000 [268:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 220.0s    660f (94%) 61.48fps Trem:   0min   7mb  A-V:0.000 [268:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 220.3s    661f (94%) 61.51fps Trem:   0min   7mb  A-V:0.000 [269:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 220.7s    662f (94%) 61.50fps Trem:   0min   7mb  A-V:0.000 [269:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 221.0s    663f (94%) 61.51fps Trem:   0min   7mb  A-V:0.000 [269:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 221.3s    664f (94%) 61.53fps Trem:   0min   7mb  A-V:0.000 [269:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 221.7s    665f (95%) 61.52fps Trem:   0min   7mb  A-V:0.000 [269:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 222.0s    666f (95%) 61.51fps Trem:   0min   7mb  A-V:0.000 [269:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 222.3s    667f (95%) 61.53fps Trem:   0min   7mb  A-V:0.000 [269:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 222.7s    668f (95%) 61.54fps Trem:   0min   7mb  A-V:0.000 [269:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 223.0s    669f (95%) 61.55fps Trem:   0min   7mb  A-V:0.000 [269:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 223.3s    670f (95%) 61.54fps Trem:   0min   7mb  A-V:0.000 [269:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 223.7s    671f (95%) 61.54fps Trem:   0min   7mb  A-V:0.000 [269:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 224.0s    672f (96%) 61.56fps Trem:   0min   7mb  A-V:0.000 [269:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 224.3s    673f (96%) 61.57fps Trem:   0min   7mb  A-V:0.000 [269:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 224.7s    674f (96%) 61.57fps Trem:   0min   7mb  A-V:0.000 [269:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 225.0s    675f (96%) 61.55fps Trem:   0min   7mb  A-V:0.000 [269:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 225.3s    676f (96%) 61.56fps Trem:   0min   7mb  A-V:0.000 [269:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 225.7s    677f (96%) 61.56fps Trem:   0min   7mb  A-V:0.000 [269:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 226.0s    678f (96%) 61.57fps Trem:   0min   7mb  A-V:0.000 [269:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 226.3s    679f (97%) 61.56fps Trem:   0min   7mb  A-V:0.000 [269:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 226.7s    680f (97%) 61.56fps Trem:   0min   7mb  A-V:0.000 [269:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 227.0s    681f (97%) 61.57fps Trem:   0min   7mb  A-V:0.000 [269:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 227.3s    682f (97%) 61.58fps Trem:   0min   7mb  A-V:0.000 [269:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 227.7s    683f (97%) 61.59fps Trem:   0min   7mb  A-V:0.000 [269:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 228.0s    684f (97%) 61.58fps Trem:   0min   7mb  A-V:0.000 [269:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 228.3s    685f (97%) 61.58fps Trem:   0min   7mb  A-V:0.000 [269:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 228.7s    686f (98%) 61.58fps Trem:   0min   7mb  A-V:0.000 [268:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 229.0s    687f (98%) 61.59fps Trem:   0min   7mb  A-V:0.000 [269:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 229.3s    688f (98%) 61.60fps Trem:   0min   7mb  A-V:0.000 [269:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 229.7s    689f (98%) 61.61fps Trem:   0min   7mb  A-V:0.000 [269:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 230.0s    690f (98%) 61.59fps Trem:   0min   7mb  A-V:0.000 [269:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 230.3s    691f (98%) 61.60fps Trem:   0min   7mb  A-V:0.000 [269:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 230.7s    692f (98%) 61.60fps Trem:   0min   7mb  A-V:0.000 [268:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 231.0s    693f (99%) 61.62fps Trem:   0min   7mb  A-V:0.000 [268:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 231.3s    694f (99%) 61.62fps Trem:   0min   7mb  A-V:0.000 [268:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 231.7s    695f (99%) 61.60fps Trem:   0min   7mb  A-V:0.000 [268:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 232.0s    696f (99%) 61.60fps Trem:   0min   7mb  A-V:0.000 [268:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 232.3s    697f (99%) 61.61fps Trem:   0min   7mb  A-V:0.000 [268:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 232.7s    698f (99%) 61.62fps Trem:   0min   7mb  A-V:0.000 [268:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 233.0s    699f (100%) 61.63fps Trem:   0min   7mb  A-V:0.000 [268:0]
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x103fecfe0]AVFrame.width or height is not set
# Pos: 233.3s    700f (100%) 61.61fps Trem:   0min   7mb  A-V:0.000 [269:0]
#
# Skipping frame!
# Pos: 233.3s    701f (100%) 61.70fps Trem:   0min   7mb  A-V:0.000 [269:0]
#
# Flushing video frames.
# Writing index...
# Writing header...
# ODML: vprp aspect is 16384:11702.
#
# Video stream:  269.013 kbit/s  (33626 B/s)  size: 7846208 bytes  233.333 secs  701 frames

# %%
# %pwd
# Out:
# '/Users/adrianovaldesgomez/Documents/Adriano_Programming/Sim_Analytic_vs_Numeric_free_diff'

# %%
# %cd ..
# Out:
# /Users/adrianovaldesgomez/Documents/Adriano_Programming

# %%
# %pwd
# Out:
# '/Users/adrianovaldesgomez/Documents/Adriano_Programming'

# %%
# %cd Animacion_Free_Diff_01/
# Out:
# /Users/adrianovaldesgomez/Documents/Adriano_Programming/Animacion_Free_Diff_01

# %%
# %pwd
# Out:
# '/Users/adrianovaldesgomez/Documents/Adriano_Programming/Sim_Analytic_vs_Numeric_free_diff'

# %%
imo

# %%
thetas = np.loadtxt("Sim_Thetas_t_01.txt")

# %%
ta = np.linspace(0,40,1000)
y = np.arccos(np.exp(-(2*D*ta/R)))

# %%
plt.plot(ta,y)

# %%
np.arccos(1)
# Out:
# 0.0

# %%
np.arccos(-1)
# Out:
# 3.141592653589793

# %%
from scipy import integrate
from scipy import special

# %%
integrate?

# %%
integrate.quad(lambda x: special.jv(5,x), 0, np.pi)
# Out:
# (0.030525157118376237, 3.388973226312179e-16)

# %%
special.legendre?

# %% [markdown]
# # Necesitamos calcular la siguientes integrales

# %% [markdown]
# $$\langle \theta(t) \rangle = \sum_{n=0}^{N} \frac{2n+1}{4\pi R^2} \int_{0}^{\pi} \theta P_{n}(\cos{\theta}) \sin{\theta} \,d\theta \exp{[-n(n+1)Dt/R^2]}$$
#
#
# $$\langle \theta^2(t) \rangle = \sum_{n=0}^{N} \frac{2n+1}{4\pi R^2} \int_{0}^{\pi} \theta^2 P_{n}(\cos{\theta}) \sin{\theta} \,d\theta \exp{[-n(n+1)Dt/R^2]}$$

# %%
integrate.quad(lambda x: np.polynomial.legendre.legval(np.cos(x), 10)*np.sin(x), 0,  np.pi)
# Out:
# (19.999999999999996, 2.2204460492503126e-13)

# %%
np.polynomial.legendre.legval?

# %% [markdown]
# $x^2$

# %% [markdown]
# # Numerical integration of $P(\theta, t | 0,0)$

# %%
distribucion_weighted(0,0,1000)
# Out:
# 0.0

# %%
integrate.quad(lambda x: x*distribucion_weighted(x,1000000,10000), 0, np.pi)
# Out:
# (1.5707963267948966, 1.743934249004316e-14)

# %%
np.pi/2
# Out:
# 1.5707963267948966

# %%
integrate.quad(lambda x: (x**2)*distribucion_weighted(x,1000000,10000), 0, np.pi)
# Out:
# (2.9348022005446794, 3.2582849757652795e-14)

# %%
np.pi**2/2 - 2
# Out:
# 2.934802200544679

# %%
import time

# %%
start_time = time.time()
#theta_numint_mean_t = []
thetasqr_numint_mean_t = []
#var_theta_num_t = []
for N in range(1,20000,100):
    int_result1 = integrate.quad(lambda x: (x**2)*distribucion_weighted(x,N,10000), 0, np.pi)[0]
    #int_result2 = integrate.quad(lambda x: (x)*distribucion_weighted(x,N,1000), 0, np.pi)[0]
    #theta_numint_mean_t.append(int_result2)
    #var_theta_num_t.append(int_result1 - int_result2**2)
    thetasqr_numint_mean_t.append(int_result1)
elapsed_time = time.time() - start_time
print(elapsed_time)
# Out:
# 421.3498649597168

# %%
integrate?

# %%
tiempos2 = []
for N in range(1,20000,100):
    tiempos2.append(dt*N)

# %%
plt.plot(tiempos2, theta_numint_mean_t)

# %%
plt.plot(tiempos2, thetasqr_numint_mean_t)
plt.plot(tiempos2, 4*D*np.array(tiempos2))
plt.ylim(0,3)
# Out:
# (0, 3)

# %%
plt.plot(tiempos2, theta_num_mean_t)

# %%
4./dt
# Out:
# 5770.7801635558535

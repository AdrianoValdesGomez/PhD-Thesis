# %% [markdown]
# # Needed libraries

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
matplotlib inline

# %%
# %config InlineBackend.figure_format ='retina'

# %%
pwd
# Out:
# '/Users/adrianovaldesgomez/Documents/Adriano_Programming/AnalyticNumeric_theta_t_09012021'

# %% [markdown]
# # Imported files

# %%
y10_theta_mean = np.loadtxt("/Users/adrianovaldesgomez/Documents/Adriano_Programming/SH_Sim_Y10_03_05_2020/Y10UD_Mean_Theta_t.txt")
y10_theta_var = np.loadtxt("/Users/adrianovaldesgomez/Documents/Adriano_Programming/SH_Sim_Y10_03_05_2020/Y10UD_Var_Theta_t.txt")

# %%
y20_theta_mean = np.loadtxt("/Users/adrianovaldesgomez/Documents/Adriano_Programming/SH_Sim_Y20_03052020/Dpole_North_ini_dist_Mean_Theta_t.txt")
y20_theta_var = np.loadtxt("/Users/adrianovaldesgomez/Documents/Adriano_Programming/SH_Sim_Y20_03052020/Dpole_North_ini_dist_Var_Theta_t.txt")

# %%
y30_theta_mean = np.loadtxt("/Users/adrianovaldesgomez/Documents/Adriano_Programming/SH_SIm_Y30_03052020/SH_Y30_03052020/Y30_Mean_Theta_t2_UNIFORM.txt")
y30_theta_var = np.loadtxt("/Users/adrianovaldesgomez/Documents/Adriano_Programming/SH_SIm_Y30_03052020/SH_Y30_03052020/Y30_Var_Theta_t2_UNIFORM.txt")

# %% [markdown]
# ### Generating times

# %%
dt = np.log(2)*1e-3

# %%
tiempo = [0]
t = 0
for i in range(len(y10_theta_mean) - 1):
    t += dt
    tiempo.append(t)

# %%
tiempo = np.array(tiempo)

# %%
plt.plot(tiempo, y10_theta_mean, linestyle = ':', label = r'$\lambda Y^{0}_{1}$', color ='slategrey', linewidth=2.5)
plt.plot(tiempo, y20_theta_mean, linestyle = '-.', label = r'$\lambda Y^{0}_{2}$', color ='seagreen', linewidth=1.5)
plt.plot(tiempo, y30_theta_mean, linestyle = '--', label = r'$\lambda Y^{0}_{3}$', color ='steelblue', linewidth=1.5)
plt.hlines(np.pi/2, 0,7, linestyle = '-', label = 'Free Diffusion', color ='teal', linewidth=1.5, alpha=.25)
plt.ylabel(r'$\langle \theta(t) \rangle $', fontsize = 19)
plt.xlabel(r'$t$', fontsize = 19)
plt.ylim(1.4,2.8)
plt.legend(loc=(.5,.4), fontsize=15)
plt.savefig("Relaxation_Mean", dpi = 250)
plt.show()

# %%
plt.plot(tiempo, y10_theta_var, linestyle = ':', label = r'$\lambda Y^{0}_{1}$', color ='slategrey', linewidth=2.0)
plt.plot(tiempo, y20_theta_var, linestyle = '-.', label = r'$\lambda Y^{0}_{2}$', color ='seagreen', linewidth=1.5)
plt.plot(tiempo, y30_theta_var, linestyle = '--', label = r'$\lambda Y^{0}_{3}$', color ='steelblue', linewidth=1.5)
#plt.ylabel(r'$\langle \theta^2(t) \rangle - \langle \theta(t)\rangle^2 $', fontsize = 13, linewidth=3.0)
plt.hlines(np.pi**2/4 - 2, 0,7, linestyle = '-', label = 'Free Diffusion', color ='teal', linewidth=1.5, alpha=.25)
plt.ylabel(r' Var$ [\theta(t)] $', fontsize = 19)
plt.xlabel(r'$t$', fontsize = 19)
plt.legend(loc=(.35,.45), fontsize=15)
plt.savefig("Relaxation_Var", dpi = 250)
plt.show()

# %%
pwd
# Out:
# '/Users/adrianovaldesgomez/Documents/Adriano_Programming/AnalyticNumeric_theta_t_09012021'

# %% [markdown]
# # Histograms time evolution

# %% [markdown]
# ## Loadings

# %%
pwd
# Out:
# '/Users/adrianovaldesgomez/Documents/Adriano_Programming/AnalyticNumeric_theta_t_09012021'

# %%
x1 = np.loadtxt("/Users/adrianovaldesgomez/Documents/Adriano_Programming/SH_Sim_Y10_14_01_2021/Y10UD_Hist_Theta_t.txt")

# %%
#x2 = np.loadtxt("/Users/adrianovaldesgomez/Documents/Adriano_Programming/SH_Sim_Y20_03052020/Dpole_North_ini_dist_Hist_Theta_t.txt")
x2 = np.loadtxt("/Users/adrianovaldesgomez/Documents/Adriano_Programming/SH_Sim_Y20_15_01_2021/Y10UD_Hist_Theta_t_P0_unif.txt")

# %%
#x3 = np.loadtxt("SH_SIm_Y30_03052020/SH_Y30_03052020/Y30_Hist_Theta_t_u0_UNIFORM.txt")
x3 = np.loadtxt("/Users/adrianovaldesgomez/Documents/Adriano_Programming/SH_Y30_16012021/Y30_Hist_Theta_t_u0_UNIFORM.txt")

# %%
pwd
# Out:
# '/Users/adrianovaldesgomez/Documents/Adriano_Programming/AnalyticNumeric_theta_t_09012021'

# %%
x4 = np.loadtxt("/Users/adrianovaldesgomez/Documents/Adriano_Programming/SH_SIm_Y30_03052020/SH_Y30_03052020/Y30_Hist_Theta_t_u0_2.txt")

# %% [markdown]
# $$P'(\theta,t) = \int_0^{2 \pi} \int_0^{ \pi} \int_0^{2 \pi} P(\theta, \phi, t | \theta_0, \phi_0, t_0) P(\theta_0,\phi_0) \,d \phi_0 d \theta_0 d \phi$$
#
#
# $$P'(\theta,t) = \int_0^{2 \pi} \int_0^{ \pi} \int_0^{2 \pi} P(\theta, \phi, t | \theta_0, \phi_0, t_0) \left [ \frac{\sin{\theta_0}}{2} \right ] \,d \phi_0 d \theta_0 d \phi$$
#
#
# Plots
#
#
# $$P(\theta, t) =  P'(\theta, t)\, \sin{\theta}$$

# %%
pwd
# Out:
# '/Users/adrianovaldesgomez/Documents/Adriano_Programming'

# %%
cd AnalyticNumeric_theta_t_09012021
# Out:
# /Users/adrianovaldesgomez/Documents/Adriano_Programming/AnalyticNumeric_theta_t_09012021

# %%
pwd
# Out:
# '/Users/adrianovaldesgomez/Documents/Adriano_Programming/AnalyticNumeric_theta_t_09012021'

# %% [markdown]
# ## $Y_{1}^{0}(\theta,\phi)$

# %% [markdown]
# ### Needed components

# %%
D = 1e-1
dt = np.log(2)*1e-3
v0 = 5.0*np.sqrt(2*D)*dt
xpot = np.linspace(0,np.pi,1000)
ypot = v0*np.sqrt(3./(4*np.pi))*np.cos(xpot)/dt
#Norm1 = 1159

#xt = np.linspace(0,np.pi,1000)
#yt = (1./Norm1)*np.exp(-190*D*(np.sqrt(3./(4*np.pi)))*np.cos(xt))*np.sin(xt)


Norm1 = 5086.71
xt = np.linspace(0,np.pi,1000)
yt = (1./Norm1)*np.exp(-5.0*np.sqrt(2*D)/D *(np.sqrt(3./(4*np.pi)))*np.cos(xt))*np.sin(xt)


theta = np.linspace(0,np.pi,1000)

#pot_Y10_int = (theta)/2. - 1/4.*np.sin(2*theta)
pot_Y10_int = -np.cos(theta)
coeff_pot_Y10 = np.sqrt(3./(4*np.pi))*2*v0/D
#p0_Y10_int = (1/9.70341e13)*np.exp(coeff_pot_Y10*pot_Y10_int)*np.sin(theta)
p0_Y10_int = (1./(3.723731e7))*np.exp(coeff_pot_Y10*pot_Y10_int)*np.sin(theta)
xpot_Y10 = np.linspace(0,np.pi,1000)
ypot_Y10 = v0*np.sqrt(3./(4*np.pi))*np.cos(xpot)/dt

# %%
190*D*(np.sqrt(3./(4*np.pi)))
# Out:
# 9.283447726155478

# %%
x1.shape
# Out:
# (10001, 10000)

# %%
#l_steps = [70*i for i in range(70)]
l_steps = [0,500,1000,2000,4000]

# %%
fig = plt.figure(figsize = (7,6))
ax = fig.add_subplot(111)
#plt.rc('text', usetex = True)
for i in l_steps:
    plt.rc('text', usetex = True)
    n,bins, rectangles = ax.hist(x1[i], bins = int(( np.array(x1[i][:]).max() - np.array(x1[i][:]).min() )*40),
                                 density = True, color = "cadetblue", alpha = 0.25, edgecolor='black',
                                 linewidth=1.2, label = 'Numerical Results')
    #fig.canvas.draw()
    ax.set_xlabel(r"$\theta$", fontsize = 19)
    ax.set_ylabel(r'$\overline{P}(\theta,t)$', size=19)

    #plt.title(r"$P(\theta,t \to \infty | \theta_0, t_0)$", fontsize = 15)
    plt.plot(xpot, 0.5*np.sin(xpot), color = "g", linestyle = "--",label = r"$P(\theta,0) = \frac{1}{2}\,\sin{\theta}$")


#ax.fill_between(xt, yt,y2 = 0, color = '#778899', alpha = .850, label=r'$P(\theta, \infty) = N \,\exp{[-U(\theta)]}$')
#ax.plot(xt, yt, color = 'black', alpha = 0.850, linewidth=1.0)
#color = '#778899'

ax.set_xlim(0,np.pi)
ax.set_ylim(-1.5,3)

ax2 = ax.twinx()

ax2.plot(xpot, ypot_Y10, color = "r", label = r"$U(\theta) =\lambda Y_{1}^{0}(\theta, \phi)$")
ax2.tick_params(axis='y', labelcolor='r')

#ax.legend(loc=3, fontsize = 10)

#ax2.legend(loc=(.01,.7), fontsize = 10)
ax2.legend(loc=(.2, .05), fontsize=15)
plt.savefig("Y10_Hist_Theta_tinf", dpi = 250)

plt.show()

# %%
pwd
# Out:
# '/Users/adrianovaldesgomez/Documents/Adriano_Programming/AnalyticNumeric_theta_t_09012021'

# %% [markdown]
# ## Sationary State

# %%
fig = plt.figure(figsize = (7,6))
ax = fig.add_subplot(111)


plt.rc('text', usetex = True)
n,bins, rectangles = ax.hist(x1[-3], bins = int(( np.array(x1[-1][:]).max() - np.array(x1[-1][:]).min() )*50),
                                 density = True, color = "cadetblue", alpha = 0.5, edgecolor='black',
                                 linewidth=1.2, label = 'Numerical Results')
    #fig.canvas.draw()
ax.set_xlabel(r"$\theta$", fontsize = 19)
#ax.set_ylabel(r'$\overline{P}(\theta)$', size=19)
    #plt.title(r"$P(\theta,t \to \infty | \theta_0, t_0)$", fontsize = 15)
plt.plot(xpot, 0.5*np.sin(xpot), color = "g", linestyle = "--",
         label = r"$P(\theta_0,0) = \frac{1}{2}\,\sin{\theta_0}$")


#ax.fill_between(xt, yt,y2 = 0, color = '#778899', alpha = .850, label=r'$P(\theta, \infty) = N \,\exp{[-U(\theta)]}$')
ax.plot(xt, yt, color = 'black', alpha = 0.850, linewidth=1.0, 
        label = r'$P(\theta, \infty) = N\,\exp{[-U_{eff}(\theta)]}$')
#color = '#778899'

ax.set_xlim(0,np.pi)
ax.set_ylim(-1.5,3)

ax2 = ax.twinx()

ax2.plot(xpot, ypot_Y10, color = "r", label = r"$U(\theta) =\lambda Y_{1}^{0}(\theta, \phi)$")
ax2.tick_params(axis='y', labelcolor='r')

ax.legend(loc=(0.29,.75), fontsize = 14)

ax2.legend(loc=(.01,.7), fontsize = 10)
ax2.legend(loc=(.2, .05), fontsize=15)
plt.savefig("Y10_Hist_Theta_stationary", dpi = 250)

plt.show()

# %%
pwd
# Out:
# '/Users/adrianovaldesgomez/Documents/Adriano_Programming/AnalyticNumeric_theta_t_09012021'

# %% [markdown]
# ## $Y_{2}^{0}(\theta,\phi)$

# %% [markdown]
# ### Needed components

# %%
D = 1e-1
dt = np.log(2)*1e-3
v0 = 5.0*np.sqrt(2*D)*dt



xpot2 = np.linspace(0,np.pi,1000)
ypot2 = -v0*np.sqrt((5/(np.pi)))*(3*np.cos(xpot2)**2 - 1)/dt



theta2 = np.linspace(0,np.pi,1000)

#Norm2 = 12300
#const = v0*2*D*np.sqrt(5./(16*np.pi))
#p0_Y20 = (1./12300)*np.exp(const*(3*np.cos(theta2)**2 - 1))*np.sin(theta2)



Norm2 = 64730.7
const = 5.0*np.sqrt(2*D)*np.sqrt(5./(16*np.pi))/D
p0_Y20_int = (1./Norm2)*np.exp(const*(3*np.cos(theta2)**2 - 1))*np.sin(theta2)


#def potential_y20(x):
#    return -v0*np.sqrt((5/(np.pi)))*(3*np.cos(x)**2 - 1)/dt

#zint = 5.0*np.sqrt(2*D)*4*np.sin(xpot)**3/(3.*D)
#p0_Y20_int = (1/0.0628306)*np.exp(-6*np.sqrt(5./(16*np.pi))*zint)*np.sin(theta2)

#theta = np.linspace(0,np.pi,1000)

# %%
5.0*np.sqrt(2*D)*np.sqrt(5./(16*np.pi))/D
# Out:
# 7.052369794346954

# %%
x2[0]
# Out:
# array([0.90609031, 0.89485146, 2.42100983, ..., 1.18764855, 1.76731815,
#        2.35349989])

# %%
#l_steps2 = [50*i for i in range(30)]
l_steps2 = [0,500,750,1000,1200]

# %%
fig = plt.figure(figsize=(7,6))
ax = fig.add_subplot(111)

for i in l_steps2:

    plt.rc('text', usetex = True)
    n,bins, rectangles = ax.hist(x2[i], bins = int(( np.array(x2[i][:]).max() - np.array(x2[i][:]).min() )*50),
                                 density = True, color = "cadetblue", alpha = 0.25,
                                 edgecolor='black', linewidth=1.2, label='Numerical Results')
    #fig.canvas.draw()
    #ax.plot(theta, p0_Y20_int, label = r'$P(\theta, \infty) = N\,\exp{[-\Phi(\theta)]}$', linewidth=2.5)
    #ax.plot(theta, p0_Y20_int, linewidth=1.0, color='black', alpha=0.850)
    #ax.fill_between(theta, p0_Y20_int ,y2 = 0, color = '#778899', alpha = .350, label=r'$P(\theta, \infty) = N \,\exp{[-U(\theta)]}$')
    ax.set_xlabel(r"$\theta$", fontsize = 19)
    ax.set_ylabel(r'$\overline{P}(\theta,t)$', size=19)
    #plt.ylabel(r"$P(\theta,t = t_0| \theta_0, t_0)$", fontsize = 18)
    #plt.legend(loc = 1, fontsize = 14)
    #plt.title(r"$P(\theta,t = t_0| \theta_0, t_0)$", fontsize = 15)

ax2 = ax.twinx()

ax2.plot(xpot2, 1.0*ypot2, color = "r", linestyle = "-", label = r"$U(\theta) = \lambda Y_{2}^{0}(\theta, \phi)$")
ax2.tick_params(axis='y', labelcolor='r')
#ax2.set_xtickslabels([str(x) for x in np.lisnpace(-6,3,10)  ])

ax.plot(xpot, 0.5*np.sin(xpot), color = "g", linestyle = "--",label = r"$P(\theta,0) = \frac{1}{2}\,\sin{\theta}$")
#plt.plot(theta, p0_Y20, 'b', label = r'$P(\theta, \infty) = N\,\exp{[-\Phi(\theta)]}$')
ax.set_ylim(-1.,2.1)
plt.xlim(0,np.pi)
#plt.yscale('log')

ax2.set_ylim(-6,14)

    #ax.legend(loc=(.32, .10))
#ax2.legend(loc=(.35, .65))
ax2.legend(loc=(.3, .05), fontsize=15)
plt.savefig("Y20_Hist_Theta_tinfty_twin", dpi = 250)
plt.show()

# %%
pwd
# Out:
# '/Users/adrianovaldesgomez/Documents/Adriano_Programming/AnalyticNumeric_theta_t_09012021'

# %% [markdown]
# ## Stationary State

# %%
x2
# Out:
# array([[0.90609031, 0.89485146, 2.42100983, ..., 1.18764855, 1.76731815,
#         2.35349989],
#        [0.92301342, 0.8954566 , 2.43172358, ..., 1.20386351, 1.76514952,
#         2.37278491],
#        [0.92692946, 0.89921327, 2.43315624, ..., 1.21553539, 1.76622976,
#         2.36671902],
#        ...,
#        [0.13754287, 0.05017053, 3.05826214, ..., 0.210144  , 2.92139965,
#         2.91719754],
#        [0.14014023, 0.04711531, 3.05506544, ..., 0.2108408 , 2.92740725,
#         2.91624803],
#        [0.14381646, 0.03345932, 3.05363798, ..., 0.20589519, 2.94886341,
#         2.92773582]])

# %%
fig = plt.figure(figsize=(7,6))
ax = fig.add_subplot(111)


plt.rc('text', usetex = True)

n,bins, rectangles = ax.hist(x2[-2], bins = int(( np.array(x2[-1][:]).max() - np.array(x2[-1][:]).min() )*50),
                             density = True, color = "cadetblue", alpha = 0.5,
                             edgecolor='black', linewidth=1.2, label='Numerical Results')




#fig.canvas.draw()
ax.plot(theta, p0_Y20_int, label = r'$P(\theta, \infty) = N\,\exp{[-U_{eff}(\theta)]}$', linewidth=1., color='k')
#ax.plot(theta, p0_Y20_int, linewidth=1.0, color='black', alpha=0.850)
#ax.fill_between(theta, p0_Y20_int ,y2 = 0, color = '#778899', alpha = .350, label=r'$P(\theta, \infty) = N \,\exp{[-U(\theta)]}$')
ax.set_xlabel(r"$\theta$", fontsize = 19)
#ax.set_ylabel(r'$\overline{P}(\theta)$', size=19)
#plt.ylabel(r"$P(\theta,t = t_0| \theta_0, t_0)$", fontsize = 18)
#plt.legend(loc = 1, fontsize = 14)
#plt.title(r"$P(\theta,t = t_0| \theta_0, t_0)$", fontsize = 15)

ax2 = ax.twinx()

ax2.plot(xpot2, 1.0*ypot2, color = "r", linestyle = "-", label = r"$U(\theta) = \lambda Y_{2}^{0}(\theta, \phi)$")
ax2.tick_params(axis='y', labelcolor='r')
#ax2.set_xtickslabels([str(x) for x in np.lisnpace(-6,3,10)  ])

ax.plot(xpot, 0.5*np.sin(xpot), color = "g", linestyle = "--",
        label = r"$P(\theta_0,0) = \frac{1}{2}\,\sin{\theta_0}$")
#plt.plot(theta, p0_Y20, 'b', label = r'$P(\theta, \infty) = N\,\exp{[-\Phi(\theta)]}$')
ax.set_ylim(-1.,2.1)
plt.xlim(0,np.pi)
#plt.yscale('log')

ax2.set_ylim(-6,14)

ax.legend(loc=(.23, .70), fontsize=15)
ax2.legend(loc=(.35, .65))
ax2.legend(loc=(.3, .05), fontsize=15)
plt.savefig("Y20_Hist_Theta_Sationary", dpi = 250)
plt.show()

# %% [markdown]
# ## $Y_{3}^{0}(\theta,\phi)$

# %% [markdown]
# ## Needed components

# %%
C = np.sqrt(2*1e-1)
U0 = 5*C*1e0
D = 1e-1
dt = np.log(2)*1e-3
v0 = U0*dt

xpot3 = np.linspace(0,np.pi,100)
ypot3 = -0.5*np.sqrt((7/(4*np.pi)))*(5*np.cos(xpot3)**3 - 3*np.cos(xpot3))*U0

#const = v0*2*D*np.sqrt(5./(16*np.pi))
#p0_Y20 = (1./12300)*np.exp(const*(3*np.cos(theta2)**2 - 1))*np.sin(theta2)

coeff_pot_Y30 = (1*U0/D)*np.sqrt(7/(16*np.pi))
Norm = 1.584171e12

theta = np.linspace(0,np.pi,1000)
pot_Y30_int = (5)*np.cos(theta)**3 - (3)*np.cos(theta)



#p0_Y30_int = (1/185666)*np.exp(coeff_pot_Y30*pot_Y30_int)*np.sin(theta)


Norm3 = 181894
p0_Y30_int = (1/Norm3)*np.exp(coeff_pot_Y30*pot_Y30_int)*np.sin(theta)




ypot_Y30 = -U0*np.sqrt(7./(16*np.pi))*(5*np.cos(theta)**3 - 3*np.cos(theta))


def int_pot_y30(theta):
    return -U0*np.sqrt(7./(16*np.pi))*(5*np.cos(theta)**3 - 3*np.cos(theta))

# %%
(1*U0/D)*np.sqrt(7/(16*np.pi))
# Out:
# 8.344476472655682

# %%
#l_steps3 = [10*i for i in range(50)]
l_steps3 = [0,50,100,200,300]

# %%
fig = plt.figure(figsize=(7,6))
ax = fig.add_subplot(111)

for i in l_steps3:
    plt.rc('text', usetex = True)
    n,bins, rectangles = plt.hist(x3[i], bins = int(( np.array(x3[i][:]).max() - np.array(x3[i][:]).min() )*50),
                                  density = True, color = "cadetblue", alpha = 0.25,
                                  edgecolor='black', linewidth=1.2, label = 'Numerical Results')
    #fig.canvas.draw()
    
ax.set_xlabel(r"$\theta$", fontsize = 19)
    
ax.set_ylabel(r'$\overline{P}(\theta,t)$', size=19)
ax2 = ax.twinx()
ax2.tick_params(axis='y', labelcolor='r')

ax2.plot(xpot3,ypot3, color = "r", linestyle = "-", label = r"$U(\theta) = -\lambda Y_{3}^{0}(\theta, \phi)$")
ax.plot(xpot, 0.5*np.sin(xpot), color = "g", linestyle = "--",label = r"$P(\theta,0) = \frac{1}{2}\,\sin{\theta}$")
ax.set_ylim(-1.0,3.0)
ax.set_xlim(0,np.pi)

    #ax.fill_between(theta, p0_Y30_int ,y2 = 0, color = '#778899', alpha = .350, linewidth=3,#
    #                label=r'$P(\theta, \infty) = N \,\exp{[-\Phi(\theta)]}$')

    #ax.plot(theta, p0_Y30_int , color = 'black', alpha = .850, linewidth=1)

#ax.legend(loc=(.05, .75))

ax2.legend(loc=(.2, .05), fontsize=15)

plt.savefig("Y30_Hist_Theta_t0_twin", dpi = 250)


plt.show()

# %% [markdown]
# ## Stationary States

# %%
fig = plt.figure(figsize=(7,6))
ax = fig.add_subplot(111)


plt.rc('text', usetex = True)
n,bins, rectangles = plt.hist(x3[i], bins = int(( np.array(x3[-1][:]).max() - np.array(x3[-1][:]).min() )*50),
                              density = True, color = "cadetblue", alpha = 0.5,
                              edgecolor='black', linewidth=1.2, label = 'Numerical Results')
#fig.canvas.draw()
    
ax.set_xlabel(r"$\theta$", fontsize = 19)
    
#ax.set_ylabel(r'$\overline{P}(\theta)$', size=19)

ax2 = ax.twinx()
ax2.tick_params(axis='y', labelcolor='r')

ax2.plot(xpot3,ypot3, color = "r", linestyle = "-", label = r"$U(\theta) = -\lambda Y_{3}^{0}(\theta, \phi)$")
ax.plot(xpot, 0.5*np.sin(xpot), color = "g", linestyle = "--",
        label = r"$P(\theta_0,0) = \frac{1}{2}\,\sin{\theta_0}$")
ax.set_ylim(-1.0,3.0)
ax.set_xlim(0,np.pi)

    #ax.fill_between(theta, p0_Y30_int ,y2 = 0, color = '#778899', alpha = .350, linewidth=3,#
    #                label=r'$P(\theta, \infty) = N \,\exp{[-\Phi(\theta)]}$')

    #ax.plot(theta, p0_Y30_int , color = 'black', alpha = .850, linewidth=1)

ax.legend(loc=(.05, .75), fontsize=15)

ax2.legend(loc=(.2, .05), fontsize=15)

plt.savefig("Y30_Hist_Theta_t0_twin", dpi = 250)


plt.show()

# %%
x4
# Out:
# array([[0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.003067  , 0.00125761, 0.00541561, ..., 0.03323732, 0.01448818,
#         0.00969864],
#        [0.01297011, 0.01191924, 0.01291794, ..., 0.03281674, 0.04249997,
#         0.01190349],
#        ...,
#        [0.07997829, 0.05725268, 0.14095565, ..., 0.11717668, 0.19770957,
#         0.22705814],
#        [0.09118203, 0.04552268, 0.13753581, ..., 0.14456715, 0.19417976,
#         0.21776185],
#        [0.09025119, 0.05099717, 0.14063637, ..., 0.13804615, 0.18041559,
#         0.19150443]])

# %%
fig = plt.figure(figsize=(7,6))
ax = fig.add_subplot(111)


plt.rc('text', usetex = True)
n,bins, rectangles = plt.hist(x4[-1], bins = int(( np.array(x4[-1][:]).max() - np.array(x4[-1][:]).min() )*50),
                              density = True, color = "cadetblue", alpha = 0.5,
                              edgecolor='black', linewidth=1.2, label = 'Numerical Results')
#fig.canvas.draw()
    
ax.set_xlabel(r"$\theta$", fontsize = 19)
    
#ax.set_ylabel(r'$\overline{P}(\theta)$', size=19)

ax2 = ax.twinx()
ax2.tick_params(axis='y', labelcolor='r')

ax2.plot(xpot3,ypot3, color = "r", linestyle = "-", label = r"$U(\theta) = -\lambda Y_{3}^{0}(\theta, \phi)$")
ax.plot(xpot, 0.5*np.sin(xpot), color = "g", linestyle = "--",
        label = r"$P(\theta_0,0) = \delta(\theta_0)$")
ax.set_ylim(-1.0,6.5)
ax.set_xlim(0,np.pi)

    #ax.fill_between(theta, p0_Y30_int ,y2 = 0, color = '#778899', alpha = .350, linewidth=3,#
    #                label=r'$P(\theta, \infty) = N \,\exp{[-\Phi(\theta)]}$')

ax.plot(theta, p0_Y30_int , color = 'black', alpha = .850, linewidth=1,
        label=r'$P(\theta, \infty) = N \,\exp{[-U_{eff}(\theta)]}$')

ax.legend(loc=(.1, .75), fontsize=15)

ax2.legend(loc=(.2, .05), fontsize=15)

plt.savefig("Y30_Hist_Theta_t0_twin_NP", dpi = 250)


plt.show()

# %%
pwd
# Out:
# '/Users/adrianovaldesgomez/Documents/Adriano_Programming/AnalyticNumeric_theta_t_09012021'

# %% [markdown]
# ## Autocorrelation function analysis

# %%
auto_1 = np.loadtxt("/Users/adrianovaldesgomez/Documents/Adriano_Programming/SH_Sim_Y10_17_01_2021/autocorr_pos_t1_1000p.txt")
auto_2 = np.loadtxt("/Users/adrianovaldesgomez/Documents/Adriano_Programming/SH_Sim_Y20_15_01_2021/autocorr_pos_t2_1000p.txt")
auto_3 = np.loadtxt("/Users/adrianovaldesgomez/Documents/Adriano_Programming/autocorr_pos_t3_1000p.txt")
auto_4 = np.loadtxt("/Users/adrianovaldesgomez/Documents/Adriano_Programming/AnalyticNumeric_theta_t_09012021/autocorr_pos_t4.txt")

# %%
tiempos = []
suma = 0.
for i in range(auto_1.shape[0]):
    suma =+ i*dt
    tiempos.append(suma)

# %%
fig = plt.figure(figsize=(7,6))
plt.rc('text', usetex = True)
plt.plot(tiempos, auto_1, label=r'$\lambda Y_{1}^{0}(\theta,\phi)$', linestyle=':', linewidth=2.0, color='slategrey')
plt.plot(tiempos, auto_2, label=r'$\lambda Y_{2}^{0}(\theta,\phi)$', linestyle='-.', linewidth=1.5, color='seagreen')
plt.plot(tiempos, auto_3, label=r'$\lambda Y_{3}^{0}(\theta,\phi)$', linestyle='--', linewidth=1.5, color='steelblue')
#plt.plot(tiempos, auto_4, label=r'Free Diffusion', linestyle='-', linewidth=5.5, color='teal', alpha=.25)
plt.plot(tiempos, np.exp(-(2*D*np.array(tiempos))), label='Free diffusion', alpha=.75)
#plt.plot(tiempos, np.exp(-(2*D*np.array(tiempos))), label='Free Diffusion')
plt.xlabel(r"$t$", fontsize=19)
plt.ylabel(r"$\langle \mathbf{n}(t)\cdot \mathbf{n}(0) \rangle$", fontsize=19)
plt.legend(fontsize=17);
plt.savefig("Autocorrelations_t20", dpi=250)

# %%
pwd
# Out:
# '/Users/adrianovaldesgomez/Documents/Adriano_Programming/AnalyticNumeric_theta_t_09012021'

# %% [markdown]
# ## More about autocorrelation function

# %%
path = "/Users/adrianovaldesgomez/Documents/Adriano_Programming"

# %%
auto_12 = np.loadtxt("/Users/adrianovaldesgomez/Documents/Adriano_Programming/SH_Sim_Y10_17_01_2021/autocorr_pos_t_D1000_10000p_Nm_3000.txt")
auto_22 = np.loadtxt("/Users/adrianovaldesgomez/Documents/Adriano_Programming/SH_Sim_Y20_15_01_2021/autocorr_pos_t_D1000_10000p_Nm_3000.txt")
auto_32 = np.loadtxt("/Users/adrianovaldesgomez/Documents/Adriano_Programming/autocorr_pos_t_D1000_10000p_Nm_3000.txt")
#auto_42 = np.loadtxt("/Users/adrianovaldesgomez/Documents/Adriano_Programming/AnalyticNumeric_theta_t_09012021/autocorr_pos_t4.txt")


auto_13 = np.loadtxt("/Users/adrianovaldesgomez/Documents/Adriano_Programming/SH_Sim_Y10_17_01_2021/autocorr_pos_t_D10000_10000p_Nm_3000.txt")
auto_23 = np.loadtxt("/Users/adrianovaldesgomez/Documents/Adriano_Programming/SH_Sim_Y20_15_01_2021/autocorr_pos_t_D10000_10000p_Nm_3000.txt")
auto_33 = np.loadtxt("/Users/adrianovaldesgomez/Documents/Adriano_Programming/autocorr_pos_t_D10000_10000p_Nm_3000.txt")
#auto_42 = np.loadtxt("/Users/adrianovaldesgomez/Documents/Adriano_Programming/AnalyticNumeric_theta_t_09012021/autocorr_pos_t4.txt")

# %%
tiempos12 = []
suma = 0.
for i in range(auto_12.shape[0]):
    suma =+ i*dt
    tiempos12.append(suma)

# %%
fig = plt.figure(figsize=(7,6))
plt.rc('text', usetex = True)
plt.plot(tiempos12, auto_12, label=r'$\lambda Y_{1}^{0}(\theta,\phi)$', linestyle=':', linewidth=2.0, color='slategrey')
plt.plot(tiempos12, auto_22, label=r'$\lambda Y_{2}^{0}(\theta,\phi)$', linestyle='-.', linewidth=1.5, color='seagreen')
plt.plot(tiempos12, auto_32, label=r'$\lambda Y_{3}^{0}(\theta,\phi)$', linestyle='--', linewidth=1.5, color='steelblue')
#plt.plot(tiempos, auto_4, label=r'Free Diffusion', linestyle='-', linewidth=5.5, color='teal', alpha=.25)


plt.plot(tiempos12, auto_13, label=r'$\lambda Y_{1}^{0}(\theta,\phi)$', linestyle=':', linewidth=2.0, color='r')
plt.plot(tiempos12, auto_23, label=r'$\lambda Y_{2}^{0}(\theta,\phi)$', linestyle='-.', linewidth=1.5, color='r')
plt.plot(tiempos12, auto_33, label=r'$\lambda Y_{3}^{0}(\theta,\phi)$', linestyle='--', linewidth=1.5, color='r')
#plt.plot(tiempos, auto_4, label=r'Free Diffusion', linestyle='-', linewidth=5.5, color='teal', alpha=.25)

plt.plot(tiempos12, np.exp(-(2*300*np.array(tiempos12))), label='Free diffusion', alpha=.75)

plt.xlabel(r"$t$", fontsize=19)
plt.ylabel(r"$\langle \mathbf{n}(t)\cdot \mathbf{n}(0) \rangle$", fontsize=19)
plt.legend(fontsize=17)
plt.xlim(0,.05);
#plt.savefig("Autocorrelations_t20", dpi=250)

# %%
from scipy.optimize import curve_fit

# %%
np.exp(2) -1. + 3*np.sin(2.)
# Out:
# 9.116948379407695

# %%
np.sin(2)
# Out:
# 0.9092974268256817

# %%
np.exp(2)
# Out:
# 7.38905609893065

# %%
np.exp(1)
# Out:
# 2.718281828459045

# %%
# coding: utf-8
import numpy as np
from matplotlib import pyplot as plt
def orto(x):
    if np.dot(x,x) == 0:
        return 'No se puede: ese es el vector cero!'
    else:
        if 0 not in x:
            v1 = 1
            v2 = -(x[0]/x[1])
            v3 = 0
            #return np.array([v1,v2,v3])
        else:
            if x[0] == 0:
                if x[1] == 0:
                    v1 = 1
                    v2 = 0
                    v3 = 0
                else:
                    v1 = 0
                    v2 = 0
                    v3 = 1
            elif x[1] == 0:
                v1 = 0
                v2 = 1
                v3 = 0
            else:
                v1 = 0
                v2 = 0
                v3 = 1
        return np.array([v1,v2,v3])
    
#Funcion que regresa dos vectores; numpy arrays de 3D, ortogonales al vector de input x.
#Esto es, devuelven la base al espacio ortogonal definido por el vector x de entrada.
#@jit
def base_ort_nor(x):
    y = orto(x)
    v1 = y/np.linalg.norm(y)
    z = np.cross(x,v1)
    v2 = z/np.linalg.norm(z)
    return v1, v2


#Esta funcion genera un vector con distrubucion uniforme en las direcciones sobre un plano tangente a la esfera de radio R.
#@jit
def vector_des(v1,v2):
    na = 2*np.pi*np.random.rand()
    vn = v1*np.cos(na) + v2*np.sin(na)
    return vn/np.linalg.norm(vn)

R = 1.

#Normalizamos al vector de desplazamiento para que intersecte al vector de la nueva posicion de acuerdo con que el
#desplazamiento (s) sobre la esfera, sobre este arco de circulo maximo, sea el determinado por el movimiento browniano particular.
#@jit

######################################## VECTOR_Q NORMALIZADO FUERA DE TIEMPO##############################
######################################## VECTOR_Q SOBRE ESCRITO ABAJO, AL FINAL DEL CODIGO ################

def vector_q(x,s):
    q = (R)*np.tan(s/(R))
    return q*x

#Dados todos los datos anteriores, esta funcion actualiza la posicion de la particula.
#Lo que hace es que la mueve sobre el plano tangente a la esfera en la direccion predeterminada de tal suerte que el desplazamiento efectivo
#s sobre una geodesica de la esfera, se el deseado, y posteriormente la proyecta sobre la superficie de la esfera.
#@jit
def nuevo_r(r, vector_q):
    y = r + vector_q
    y = y/np.linalg.norm(y)
    return (R)*y

#funcion que incorpora el efecto de un campo externo



#Esta funcion ensambla todo lo anterior: como imput necesita una posicion inicial y un arco de desplazamiento
#Como output da un vector de posicion nuevo dada un tipo de desplazamiento.
#@jit
def actualiza(r,s):
    v1, v2 = base_ort_nor(r)
    pre_q = vector_des(v1,v2)
    q = vector_q(pre_q, s)
    return nuevo_r(r, q)




#Esta funcion actualiza la posicion de todos los elementos de una lista; particula brownianas.
#@jit


def act_n(lista, D, delta_t):
    l = []
    for v in lista:
        s = ese(D,delta_t)
        l.append(actualiza(v,s))
    return l



#Huella de la trayectoria
#La siguiente funcion hace una particion de la trayectoria sobre s en n pedazos y regresa
#una lista de los vectores de esas posiciones sobre la esfera.
#Usa al operador de rotacion.

#@jit
def b_steps_(ri,rf,n):
    l = [ri]
    r0 = ri
    lamb = (np.dot(ri,rf))/((np.linalg.norm(ri))*(np.linalg.norm(rf)))
    
    if abs(lamb) > 1:
        #print 'Is fucked up: there was a rounding '
        if lamb < 0:
            lamb = -1
        else:
            lamb = 1
    
    
    
    theta = np.arccos(lamb)
    #if theta < 1e17:
        #return l
    if theta == 0:
        return [ri,rf]
    
    else:

        normal = np.cross(ri, rf)/ np.linalg.norm(np.cross(ri,rf))
        for i in range(1,n + 1):
            #vi = rot_theta(r0, theta/n, normal)
            vi = rot_finita(r0, -normal, theta/n)
            l.append(vi)
            r0 = vi
        return l


#Operador de Rotacion
#Depende de los parametros r, el vector o punto que queremos rotar; theta el angulo de rotacion; n el vector que define el eje de rotacion y el signo de rotacion.


#@jit
def rot_theta(r, theta, u):
    x = np.array([np.cos(theta) + (u[0]*u[0])*(1 - np.cos(theta)), u[0]*u[1]*(1 - np.cos(theta)) - u[2]*np.sin(theta), u[0]*u[2]*(1 - np.cos(theta)) + u[1]*np.sin(theta)])
    y = np.array([u[1]*u[0]*(1 - np.cos(theta)) + u[2]*np.sin(theta), np.cos(theta) + u[1]*u[1]*(1 - np.cos(theta)), u[1]*u[2]*(1 - np.cos(theta)) - u[0]*np.sin(theta)])
    z = np.array([u[2]*u[0]*(1 - np.cos(theta)) - u[1]*np.sin(theta), u[2]*u[1]*(1 - np.cos(theta)) + u[0]*np.sin(theta), np.cos(theta) + u[2]*u[2]*(1 - np.cos(theta))])
    R = np.array([x,y,z])
    return np.dot(R, r)



#Transformacion de coordenada de esfericas a cartesianas.

#@jit
def trans_s_c(r,theta, phi):
    x = r*np.sin(theta)*np.cos(phi)
    y = r*np.sin(theta)* np.sin(phi)
    z = r*np.cos(theta)
    return x, y, z



def trans_c_s(x,y,z):
    r = np.sqrt(x**2 + y**2 + z**2)
    #print r
    cociente = z/r
    if abs(cociente) > 1:
        if cociente < 0:
            theta = np.arccos(-1)
        else:
            theta = np.arccos(1)
    else:
        
        theta = np.arccos(z/r)
    #Aqui hay un problema relevante: cada vez que y o x sean nulos, habra un problema
    #de indefinicion de operacion
    if x == 0.:
        if y == 0.:
            phi = 2*np.pi*np.random.rand()
    else:
        if x < 0:
            phi = np.arctan(y/x) + np.pi
        else:
            if y < 0:
                phi = np.arctan(y/x) + 2*np.pi
            else:
                
                phi = np.arctan(y/x)
    return r, theta, phi




#Base unitaria para las coordenadas esféricas
#@jit
def r_uni(theta, phi):
    x = np.sin(theta)*np.cos(phi)
    y = np.cos(theta)*np.cos(phi)
    z = np.cos(theta)
    return np.array([x,y,z])
#@jit
def theta_uni(theta, phi):
    x = np.cos(theta)*np.cos(phi)
    y = np.cos(theta)*np.sin(phi)
    z = -np.sin(theta)
    return np.array([x,y,z])
#@jit
def phi_uni(theta, phi):
    x = -np.sin(phi)
    y = np.cos(phi)
    z = 0
    return np.array([x,y,z])

#Función que normaliza los nombres para las animaciones de tal suerte que tenga el mismo número de
#digitos y se iteren en orden
#@jit
def nombre(s):
    diferencia = 4 - len(str(s))
    ceros = '' 
    for i in range(diferencia):
        ceros = ceros + '0'
    variable = ceros + str(s)
    return variable

#Varianza para una distribucion bigaussiana; difusion en 2D
#@jit
def var(D, delta_t):
    return 4*D*delta_t


#Arco de circulo maximo con distribucion normal alrededor de cero y una varianza dada por
#@jit
def ese(D,delta_t):
    return abs(np.random.normal(loc = 0., scale = np.sqrt(var(D,delta_t)),size = None))

#Funcion de rotacion finita
#@jit
def rot_finita(r_ini, N, Phi):
    n = N/np.linalg.norm(N)
    r_fin = np.cos(Phi)*r_ini + (np.dot(n,r_ini))*(1 - np.cos(Phi))*n + (np.sin(Phi))*(np.cross(r_ini,n))
    return r_fin


#Funcion que regresa una lista de n numpy arrays que son l
def Trayectoria(ri,rf,n):
    l = [ri]
    r0 = ri
    theta = np.arccos((np.dot(ri,rf))/((np.linalg.norm(ri))*(np.linalg.norm(rf))))
    N = np.cross(ri, rf)
    
    for i in range(1,n + 1):
        vi = rot_finita(r0, N, theta/n)
        l.append(vi)
        r0 = vi
    return l

#Collision_check es una función que, dada una trayectoria: una lista de vectores que
#pasan por puntos sucesivos de la trayectoria, verifica si alguna de estas posiciones
#interesecto a alguno de los obstáculos. En caso de que así sea, actualiza conforme una
#colision elastica. En caso de no intersectar a ningun obstaculo regresa una lista
#con dos vectores: posicion inicial y posicion final en ese orden.
#@jit
def penetrate_obs(lista_vect, lista_obs, size):
    metiches = []
    for obs in lista_obs:
        theta_omega = size
        r_omega = obs
        frontera = .2
        #metiches = []
        for v in lista_vect:
            tamanho = np.cos(theta_omega - frontera)
            if np.dot(v,r_omega) > tamanho:
                print('Penetro el mother fucker obstacle')
                metiches.append(v)
                
            else:
                continue
    #print 'no choco el mother fucker'
    #valor = False
    return metiches


#Esta funcion cuando es llamada grafia la posicion de las partoculas brownianas.
#sobre la superficie de una esfera sobre la que se esta difundiendo.
#@jit
def plot_particles(lista, vpolar, vazim, numero):
    from mpl_toolkits.mplot3d import axes3d
    from mpl_toolkits.mplot3d import Axes3D
    from matplotlib import cm

    #import matplotlib.pyplot as plt
    #import numpy as np
    from itertools import product, combinations
    fig = plt.figure(figsize=(8,8))
    ax = fig.gca(projection='3d')
    ax.set_aspect("equal")
    ax._axis3don = False

    



    #draw sphere
    R = 1
    u, v = np.mgrid[0:2*np.pi:50j, 0:np.pi:50j]
    x=R*np.cos(u)*np.sin(v)
    y=R*np.sin(u)*np.sin(v)
    z=R*np.cos(v)
    #ax.plot_surface(x, y, z, color="r", alpha = 0.15)

    ax.plot_surface(x, y, z, cmap=cm.YlGnBu_r,rstride=1, cstride=1, alpha = 0.10, linewidth = 0.10)
    ax.view_init(vpolar, vazim)
    
    
    #draw an arrow or a set of arrow
    #ax.quiver(0,0,1.5,0,0,1, length=0.5, arrow_length_ratio = .5, color = "b")
    #ax.quiver(1.5,0,0,1,0,0, length=0.5, arrow_length_ratio = .5, color ="g")
    #ax.quiver(0,1.5,0,0,1,0, length=0.5, arrow_length_ratio = .5, color ="r")
    #draw patch
    #u, v = np.mgrid[0:2*np.pi:50j, 0:(np.pi/7):50j]
    #x=R*np.cos(u)*np.sin(v)
    #y=R*np.sin(u)*np.sin(v)
    #z=R*np.cos(v)
    #ax.plot_surface(x, y, z, color="r", alpha = 0.25)    
    
    #draw points
    for p in lista:
        ax.scatter([p[0]],[p[1]],[p[2]],color="b",s=15, alpha = 0.25)
    
    fig.savefig('SHY10_Field_X01_Img{}.png'.format(nombre(numero)))
    #ax.view_init(80, 30)
    #plt.show()
    plt.close()

    
    
#@jit
def polo_n(n, R):
    l = []
    for i in range(n):
        l.append(np.array([0,0,R]))
    return l

#@jit
def particion_esfera(ccero, Nphi):
    Ntheta = int(4*np.pi/(ccero*Nphi))
    print('Ntheta', Ntheta, 'Nphi', Nphi, 'Ntheta*Nphi', Ntheta*Nphi)
    sigmaPhi = 2*np.pi/Nphi
    deltaphi = 2*np.pi/Nphi
    thetas = []
    phis = [0]
    cociente = ccero/sigmaPhi
    for i in range(Ntheta + 1):
        theta = np.arccos(1 - (i)*cociente)
        thetas.append(theta)
    for j in range(Nphi):
        phis.append(phis[j] + deltaphi)
    return thetas, phis

#@jit
def secuencia_part(tamini, Nfi, numero):
    l1, l2 = particion_esfera(4*np.pi/tamini, Nfi)
    particion = []
    for i in range(len(l2)):
        for j in range(len(l1)):
            x, y, z = trans_s_c(1, l1[j], l2[i])
            particion.append(np.array([x, y, z]))
            
    return plot_particles(particion, 45, 45, numero)

#Funcion que regresa las coordenadas del centro de dos arreglos para 
#las coordenadas theta y phi
#@jit
def coordenadas_centro(l1,l2):
    thetas_centro = []
    phis_centro = []
    for i in range(len(l1) - 1):
        theta_media = l1[i] + (l1[i + 1] - l1[i])/2.
        thetas_centro.append(theta_media)
    for j in range(len(l2) - 1):
        phi_media = l2[j] + (l2[j + 1] - l2[j])/2.
        phis_centro.append(phi_media)
    return thetas_centro, phis_centro

#@jit(nopython=True)
def secuencia_obs(N, Nfi, numero):
    l1_prima, l2_prima = particion_esfera(4*np.pi/N, Nfi)
    l1, l2 = coordenadas_centro(l1_prima, l2_prima)
    particion = []
    for i in range(len(l2)):
        for j in range(len(l1)):
            x, y, z = trans_s_c(1, l1[j], l2[i])
            particion.append(np.array([x, y, z]))
            
    print(len(particion))
    
    #return plot_particles(particion, 0, 0, numero)
    return particion


def plot_particle_traj_obs(lista_obstaculos, trayectoria,  vpolar, vazim, numero):
    from mpl_toolkits.mplot3d import axes3d
    from mpl_toolkits.mplot3d import Axes3D
    from matplotlib import cm

    #import matplotlib.pyplot as plt
    #import numpy as np
    from itertools import product, combinations
    fig = plt.figure(figsize=(20,10))
    ax = fig.gca(projection='3d')
    ax.set_aspect("equal")
    ax._axis3don = False
    

    



    #draw sphere
    R = 1
    u, v = np.mgrid[0:2*np.pi:50j, 0:np.pi:50j]
    x=R*np.cos(u)*np.sin(v)
    y=R*np.sin(u)*np.sin(v)
    z=R*np.cos(v)
    #ax.plot_surface(x, y, z, color="r", alpha = 0.15)

    ax.plot_surface(x, y, z, cmap=cm.YlGnBu_r,rstride=1, cstride=1, alpha = 0.10, linewidth = 0.15)
    ax.view_init(vpolar, vazim)
    #draw patch
    #u, v = np.mgrid[0:2*np.pi:50j, 0:(np.pi/7):50j]
    #x=R*np.cos(u)*np.sin(v)
    #y=R*np.sin(u)*np.sin(v)
    #z=R*np.cos(v)
    #ax.plot_surface(x, y, z, color="r", alpha = 0.25)
    
    
    
    #draw obstacles
    
    for p in lista_obstaculos:
        ax.scatter([p[0]],[p[1]],[p[2]], color="b", s=10, alpha = 0.2)
    
    #draw trajectory
    for p in trayectoria:
        ax.scatter([p[0]],[p[1]],[p[2]], color="k",s=20, alpha = 0.7)
    
    #Plot the x positive direction
    
    ax.quiver(1.5,0,0,1,0,0, length=0.5, arrow_length_ratio = .5)
    ax.quiver(0,1.5,0,0,1,0, length=0.5, arrow_length_ratio = .5)
    ax.quiver(0,0,1.5,0,0,1, length=0.5, arrow_length_ratio = .5)
    
    #fig.savefig('BS_24_Obs_test_01{}.png'.format(nombre(numero + 1)))
    #ax.view_init(80, 30)
    #plt.close()
    plt.show()

def obs_uniforme(N, R, size):
    
    list_obs = []
    omega = np.cos(size)
    while len(list_obs) < N:
        x, y, z = np.random.uniform(-1,1), np.random.uniform(-1,1), np.random.uniform(-1,1)
        v = np.array([x, y, z])
        norma = np.linalg.norm(v)
        if norma <= R:
            n = v/norma
            if not np.dot(n, np.array([0.,0.,1.]))/R > omega:
                list_obs.append(R*n)
    
    return list_obs    


def puntos_obs_j(r_omega, theta_omega, n):
    r , theta, phi = trans_c_s(r_omega[0],r_omega[1],r_omega[2])
    rp = rot_finita(r_omega, phi_uni(theta, phi), theta_omega)
    puntos_obs_j = [rp]
    for i in range(1,n):
        x = rot_finita(rp, r_omega, 2*np.pi/n)
        puntos_obs_j.append(x)
        rp = x
    return puntos_obs_j



def puntos_obs(lista_obstaculos, size):
    mis_obs = []
    for i in range(len(lista_obstaculos)):
        a = lista_obstaculos[i]
        b = size
        mis_obs = mis_obs + puntos_obs_j(a,b,100)
    return mis_obs
#Collision_check es una función que, dada una trayectoria: una lista de vectores que
#pasan por puntos sucesivos de la trayectoria, verifica si alguna de estas posiciones
#interesecto a alguno de los obstáculos. En caso de que así sea, actualiza conforme una
#colision elastica. En caso de no intersectar a ningun obstaculo regresa una lista
#con dos vectores: posicion inicial y posicion final en ese orden.

def penetrate_obs(lista_vect, lista_obs, size):
    metiches = []
    for obs in lista_obs:
        r_omega, theta_omega = obs, size
        #frontera = .2
        #metiches = []
        for v in lista_vect:
            tamanho = np.cos(theta_omega)
            if np.dot(v,r_omega) >= tamanho:
                #print 'Penetro el mother fucker obstacle'
                metiches.append(v)
                
            else:
                continue
    #print 'no choco el mother fucker'
    #valor = False
    return metiches
    

def check_collision(lista_vect, lista_obs, size):
    for obs in lista_obs:
        r_omega, theta_omega = obs, size 
        for v in lista_vect:
            tamanho = np.cos(theta_omega)
            if np.dot(v,r_omega) > tamanho:
                return  True
            else:
                continue
    return False
 

    
#############################################################################################################
#############################################################################################################
#############################################################################################################


#Hay que modificar esto cuando hay mas interacciones!!!! Al final va el rescalamiento con la tangente; no con
#cada termino individual sino con la suma en el espacio tangente.


def vector_q(x,s):
    #q = np.tan(s)
    q = s
    return q*x

#Distribución en el polo sur

def polo_s(n, R):
    l = []
    for i in range(n):
        l.append(np.array([0,0,-R]))
    return l

#Dsitribución en el ecuador

def dist_ecuador(n):
    l = []
    for i in range(n):
        x, y, z = trans_s_c(1.,np.pi/2, np.random.uniform(0,2*np.pi))
        l.append(np.array([x,y,z]))
    return l

# %%
def nuevo_r_field(r, vector_q, field):
    #nfield = np.tan(field)
    v_sum = field + vector_q
    xf = np.linalg.norm(v_sum)
    if xf == 0:
        nfield = 0
    else:
        fvecuni = (v_sum)/xf
        nfield = np.tan(xf)*fvecuni
    #y = r + vector_q + nfield
    y = r + nfield
    y = y/np.linalg.norm(y)
    return y



coff = np.sqrt((3./(4*np.pi)))

def field_theta(ri, v0):
    r, theta, phi = trans_c_s(ri[0],ri[1],ri[2])
    
    theta_field = coff*(np.sin(theta))
    
    phi_field = 0.
    
    field = v0*(theta_field)*theta_uni(theta, phi)
    
    return field

def actualiza_field_theta(r,s,v0):
    v1, v2 = base_ort_nor(r)
    pre_q = vector_des(v1,v2)
    q = vector_q(pre_q, s)
    return nuevo_r_field(r, q, field_theta(r,v0))
    #return nuevo_r_field(r, pre_q, field_theta(r,v0))


def act_n_field(lista, v0):
    l = []
    for v in lista:
        s = ese(D,dt)
        l.append(actualiza_field_theta(v, s, v0))
    return l

# %%
def mean_var_hist_theta(lista):
    thetas = []
    for r in lista:
        cociente = r[2]
        if abs(cociente) > 1.:
            if cociente < 0:
                theta = np.arccos(-1)
            else:
                theta = np.arccos(1)
        else:

            theta = np.arccos(r[2])
            
        thetas.append(theta)
        
    return thetas, np.mean(thetas), np.var(thetas)

# %%
def mean_var_hist_phis(lista):
    phis = []
    for r in lista:
        
        if r[0] == 0:
            if r[1] == 0:
                phi = 2*np.pi*np.random.rand()
        else:
            if r[0] < 0:
                
                phi = np.arctan(r[1]/r[0]) + np.pi
                    
            else:
                if r[1] < 0:
                    phi = np.arctan(r[1]/r[0]) + 2*np.pi
                else:
                
                    phi = np.arctan(r[1]/r[0])
                
        phis.append(phi)
    return phis, np.mean(phis), np.var(phis)

# %%
# %matplotlib inline

# %%
import scipy as sci
import scipy.special as sp
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm, colors

# %%
from __future__ import division
def Plot_Spherical_lm(l,m, numero,t,vp,va):
    
    PHI, THETA = np.mgrid[0:2*np.pi:200j, 0:np.pi:200j]
    R = sp.sph_harm(m, l, PHI, THETA).real
    R = np.abs(R*np.cos(2*t))
    X = R * np.sin(THETA) * np.cos(PHI)
    Y = R * np.sin(THETA) * np.sin(PHI)
    Z = R * np.cos(THETA)

    #As R has negative values, we'll use an instance of Normalize
    #see http://stackoverflow.com/questions/25023075/normalizing-colormap-used-by-facecolors-in-matplotlib
    norm = colors.Normalize()
    plt.rc("text", usetex = True)
    fig, ax = plt.subplots(subplot_kw=dict(projection='3d'), figsize=(14,10))
    m = cm.ScalarMappable(cmap=cm.jet)
    ax.plot_surface(X, Y, Z, rstride=1, cstride=1, facecolors=cm.jet(norm(R)), alpha = 0.5)
    ax.set_title(r'$ |Y_{l}^{m}(\theta, \phi)| $', fontsize=24)
    #ax.set_xlim(-0.5,0.5)
    #ax.set_ylim(-0.5,0.5)
    #ax.set_zlim(-0.5,0.5)
    m.set_array(R)
    ax.view_init(vp,va)
    fig.colorbar(m, shrink=0.8)
    #plt.savefig("SphericalHarmonicY22_{}".format(nombre(numero)))
    #plt.close();

# %%
# %matplotlib inline

# %%
phi_sh = np.linspace(0, np.pi, 120)
theta_sh = np.linspace(0, 2*np.pi, 120)
phi_sh, theta_sh = np.meshgrid(phi_sh, theta_sh)

# The Cartesian coordinates of the unit sphere
x_sh = np.sin(phi_sh) * np.cos(theta_sh)
y_sh = np.sin(phi_sh) * np.sin(theta_sh)
z_sh = np.cos(phi_sh)

l, m = 4, 3

# Calculate the spherical harmonic Y(l,m) and normalize to [0,1]
fcolors = -sp.sph_harm(m, l, theta_sh, phi_sh).real
fmax, fmin = fcolors.max(), fcolors.min()
fcolors = (fcolors - fmin)/(fmax - fmin)

# Set the aspect ratio to 1 so our sphere looks spherical
#fig = plt.figure(figsize=plt.figaspect(1.))
fig = plt.figure(figsize = (7,7))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x_sh, y_sh, z_sh,  rstride=1, cstride=1, facecolors=cm.viridis(fcolors), alpha = 0.76)
# Turn off the axis planes
ax.set_axis_off()
ax.view_init(-20,0)
plt.show()

# %%
phi_sh = np.linspace(0, np.pi, 140)
theta_sh = np.linspace(0, 2*np.pi, 140)
phi_sh, theta_sh = np.meshgrid(phi_sh, theta_sh)

# The Cartesian coordinates of the unit sphere
x_sh = np.sin(phi_sh) * np.cos(theta_sh)
y_sh = np.sin(phi_sh) * np.sin(theta_sh)
z_sh = np.cos(phi_sh)

l, m = 8, 3

# Calculate the spherical harmonic Y(l,m) and normalize to [0,1]
fcolors = -sp.sph_harm(m, l, theta_sh, phi_sh).real
fmax, fmin = fcolors.max(), fcolors.min()
fcolors = (fcolors - fmin)/(fmax - fmin)

# Set the aspect ratio to 1 so our sphere looks spherical
#fig = plt.figure(figsize=plt.figaspect(1.))
fig = plt.figure(figsize = (7,7))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x_sh, y_sh, z_sh,  rstride=1, cstride=1, facecolors=cm.viridis(fcolors), alpha = 0.76)
# Turn off the axis planes
ax.set_axis_off()
ax.view_init(-20,0)
plt.show()

# %%
for i in range(0,2):
    for j in range(0,2):
        # The Cartesian coordinates of the unit sphere
        x_sh = np.sin(phi_sh) * np.cos(theta_sh)
        y_sh = np.sin(phi_sh) * np.sin(theta_sh)
        z_sh = np.cos(phi_sh)

        l, m = i+3, j+3

        # Calculate the spherical harmonic Y(l,m) and normalize to [0,1]
        fcolors = -sp.sph_harm(m, l, theta_sh, phi_sh).real
        fmax, fmin = fcolors.max(), fcolors.min()
        fcolors = (fcolors - fmin)/(fmax - fmin)

        # Set the aspect ratio to 1 so our sphere looks spherical
        #fig = plt.figure(figsize=plt.figaspect(1.))
        fig = plt.figure(figsize = (5,5))
        ax = fig.add_subplot(111, projection='3d')
        ax.plot_surface(x_sh, y_sh, z_sh,  rstride=1, cstride=1, facecolors=cm.viridis(fcolors), alpha = 0.76)
        # Turn off the axis planes
        ax.set_axis_off()
        ax.view_init(-20,0)
        
plt.show()
# Out:
# /Users/adrianovaldesgomez/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)
# /Users/adrianovaldesgomez/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:29: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims)
# /Users/adrianovaldesgomez/anaconda3/lib/python3.6/site-packages/matplotlib/colors.py:489: RuntimeWarning: invalid value encountered in less
#   np.copyto(xa, -1, where=xa < 0.0)

# %%
l, m = 3, 3
# Calculate the spherical harmonic Y(l,m) and normalize to [0,1]
fcolors = -sp.sph_harm(m, l, theta_sh, phi_sh).real
fmax, fmin = fcolors.max(), fcolors.min()
fcolors = (fcolors - fmin)/(fmax - fmin)


# Set the aspect ratio to 1 so our sphere looks spherical
#fig = plt.figure(figsize=plt.figaspect(1.))

fig = plt.figure(figsize = (15,15))



ax1 = fig.add_subplot(231, projection='3d')
ax1.plot_surface(x_sh, y_sh, z_sh,  rstride=1, cstride=1, facecolors=cm.viridis(fcolors), alpha = 0.76)
ax1.set_axis_off()

l, m = 4, 3
# Calculate the spherical harmonic Y(l,m) and normalize to [0,1]
fcolors = -sp.sph_harm(m, l, theta_sh, phi_sh).real
fmax, fmin = fcolors.max(), fcolors.min()
fcolors = (fcolors - fmin)/(fmax - fmin)
# Set the aspect ratio to 1 so our sphere looks spherical
#fig = plt.figure(figsize=plt.figaspect(1.))
#fig = plt.figure(figsize = (7,7))
ax2 = fig.add_subplot(232, projection='3d')
ax2.plot_surface(x_sh, y_sh, z_sh,  rstride=1, cstride=1, facecolors=cm.viridis(fcolors), alpha = 0.76)
ax2.set_axis_off()


l, m = 8, 5
# Calculate the spherical harmonic Y(l,m) and normalize to [0,1]
fcolors = -sp.sph_harm(m, l, theta_sh, phi_sh).real
fmax, fmin = fcolors.max(), fcolors.min()
fcolors = (fcolors - fmin)/(fmax - fmin)
# Set the aspect ratio to 1 so our sphere looks spherical
#fig = plt.figure(figsize=plt.figaspect(1.))
#fig = plt.figure(figsize = (7,7))
ax3 = fig.add_subplot(233, projection='3d')
ax3.plot_surface(x_sh, y_sh, z_sh,  rstride=1, cstride=1, facecolors=cm.viridis(fcolors), alpha = 0.76)
ax3.set_axis_off()




#########################################################################################################

l, m = 10, 5
# Calculate the spherical harmonic Y(l,m) and normalize to [0,1]
fcolors = -sp.sph_harm(m, l, theta_sh, phi_sh).real
fmax, fmin = fcolors.max(), fcolors.min()
fcolors = (fcolors - fmin)/(fmax - fmin)
# Set the aspect ratio to 1 so our sphere looks spherical
#fig = plt.figure(figsize=plt.figaspect(1.))
#fig = plt.figure(figsize = (7,7))
ax4 = fig.add_subplot(234, projection='3d')
ax4.plot_surface(x_sh, y_sh, z_sh,  rstride=1, cstride=1, facecolors=cm.viridis(fcolors), alpha = 0.76)
ax4.set_axis_off()

l, m = 15, 3
# Calculate the spherical harmonic Y(l,m) and normalize to [0,1]
fcolors = -sp.sph_harm(m, l, theta_sh, phi_sh).real
fmax, fmin = fcolors.max(), fcolors.min()
fcolors = (fcolors - fmin)/(fmax - fmin)
# Set the aspect ratio to 1 so our sphere looks spherical
#fig = plt.figure(figsize=plt.figaspect(1.))
#fig = plt.figure(figsize = (7,7))
ax5 = fig.add_subplot(235, projection='3d')
ax5.plot_surface(x_sh, y_sh, z_sh,  rstride=1, cstride=1, facecolors=cm.viridis(fcolors), alpha = 0.76)
ax5.set_axis_off()


l, m = 20, 10
# Calculate the spherical harmonic Y(l,m) and normalize to [0,1]
fcolors = -sp.sph_harm(m, l, theta_sh, phi_sh).real
fmax, fmin = fcolors.max(), fcolors.min()
fcolors = (fcolors - fmin)/(fmax - fmin)
# Set the aspect ratio to 1 so our sphere looks spherical
#fig = plt.figure(figsize=plt.figaspect(1.))
#fig = plt.figure(figsize = (7,7))
ax6 = fig.add_subplot(236, projection='3d')
ax6.plot_surface(x_sh, y_sh, z_sh,  rstride=1, cstride=1, facecolors=cm.viridis(fcolors), alpha = 0.76)
ax6.set_axis_off()


# Turn off the axis planes
#ax1.set_axis_off()
ax.view_init(90,0)
plt.show()

# %%
# !pwd
# Out:
# /Users/adrianovaldesgomez/Documents/Adriano_Programming

# %%
# %cd ..
# Out:
# /Users/adrianovaldesgomez/Documents

# %%
# !mkdir Y10_28_10_2017

# %%
# %cd Y10_28_10_2017/
# Out:
# /Users/adrianovaldesgomez/Documents/Adriano_Programming/Y10_28_10_2017

# %%
fig = plt.figure(figsize = (5,5))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x_sh, y_sh, z_sh,  rstride=1, cstride=1, facecolors=cm.jet(fcolors), alpha = 0.2)
# Turn off the axis planes
ax.set_axis_off()
ax.view_init(90,0)
plt.savefig("TopCLSphericalHarmonicYl1m0", dpi = 150)
plt.show()

# %% [markdown]
# ### Administración de carpetas

# %%
# !pwd
# Out:
# /Users/draflorencia/Documents/Adriano/simulaciones/New_Programs/Foreign_Notebooks

# %%
# %cd ..
# Out:
# /Users/draflorencia/Documents/Adriano/simulaciones/New_Programs/Foreign_Notebooks

# %%
# !mkdir SH_Sim_Y10_01

# %%
# %cd SH_Sim_Y10_01/
# Out:
# /Users/adrianovaldesgomez/Documents/Adriano_Programming/SH_Sim_Y10_01

# %% [markdown]
# ### Simulación

# %%
D = 1e-1
dt = np.log(2)*1e-3
v0 = 20*np.sqrt(2*D)*dt
dist_uni = obs_uniforme(700, 1., 0)
#dist_uni = polo_n(600,1.)
plot_particles(dist_uni, 0, 0, 0)
rs = dist_uni
for i in range(700):
         
        nuevas_pos = act_n_field(rs, v0)
        plot_particles(nuevas_pos, 0, 0, i + 1)
        rs = nuevas_pos

# %% [markdown]
# ### Animación

# %%
# !mencoder "mf://*.png" -o SHY10_Animation_01.mov -ovc lavc -lavcopts vcodec=msmpeg4v2:autoaspect:vbitrate=2160000:mbd=2:keyint=132:vqblur=1.0:cmp=2:subcmp=2:dia=2:o=mpv_flags=+mv0:last_pred=3 -fps 20;
# Out:
# MEncoder 1.3.0-4.2.1 (C) 2000-2016 MPlayer Team
# 224 audio & 451 video codecs
#
# WARNING: OUTPUT FILE FORMAT IS _AVI_. See -of help.
# success: format: 16  data: 0x0 - 0x0
# MF file format detected.
# [mf] search expr: *.png
# [mf] number of files: 701 (5608)
# [demux_mf] file type was not set! trying 'type=png'...
# VIDEO:  [MPNG]  0x0  24bpp  25.000 fps    0.0 kbps ( 0.0 kbyte/s)
# [V] filefmt:16  fourcc:0x474E504D  size:0x0  fps:25.000  ftime:=0.0400
# Input fps will be interpreted as 20.000 instead.
# libavcodec version 57.24.102 (internal)
# Opening video filter: [expand osd=1]
# Expand: -1 x -1, -1 ; -1, osd: 1, aspect: 0.000000, round: 1
# ==========================================================================
# Opening video decoder: [ffmpeg] FFmpeg's libavcodec codec family
# Selected video codec: [ffpng] vfm: ffmpeg (FFmpeg PNG)
# ==========================================================================
# Could not find matching colorspace - retrying with -vf scale...
# Opening video filter: [scale]
# Movie-Aspect is undefined - no prescaling applied.
# [swscaler @ 0x101bce410]bicubic scaler, from rgba to yuv420p using MMXEXT
# videocodec: libavcodec (576x576 fourcc=3234504d [MP42])
# [VE_LAVC] High quality encoding selected (non-realtime)!
# Movie-Aspect is 1.00:1 - prescaling to correct movie aspect.
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Writing header...
# ODML: vprp aspect is 16384:16384.
# Writing header...
# ODML: vprp aspect is 16384:16384.
# Pos:   0.1s      1f ( 0%)  0.00fps Trem:   0min   0mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   0.1s      2f ( 0%)  0.00fps Trem:   0min   0mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   0.1s      3f ( 0%)  0.00fps Trem:   0min   0mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   0.2s      4f ( 0%)  0.00fps Trem:   0min   0mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   0.2s      5f ( 0%)  0.00fps Trem:   0min   0mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   0.3s      6f ( 0%)  0.00fps Trem:   0min   0mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   0.3s      7f ( 1%)  0.00fps Trem:   0min  12mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   0.4s      8f ( 1%)  0.00fps Trem:   0min  14mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   0.5s      9f ( 1%)  0.00fps Trem:   0min  16mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   0.5s     10f ( 1%)  0.00fps Trem:   0min  18mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   0.6s     11f ( 1%)  0.00fps Trem:   0min  20mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   0.6s     12f ( 1%)  0.00fps Trem:   0min  22mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   0.7s     13f ( 1%)  0.00fps Trem:   0min  23mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   0.7s     14f ( 2%)  0.00fps Trem:   0min  12mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   0.8s     15f ( 2%)  0.00fps Trem:   0min  13mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   0.8s     16f ( 2%)  0.00fps Trem:   0min  13mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   0.8s     17f ( 2%)  0.00fps Trem:   0min  14mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   0.9s     18f ( 2%)  0.00fps Trem:   0min  15mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   0.9s     19f ( 2%)  0.00fps Trem:   0min  15mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   1.0s     20f ( 2%)  0.00fps Trem:   0min  16mb  A-V:0.000 [0:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   1.1s     21f ( 3%)  0.00fps Trem:   0min  11mb  A-V:0.000 [2731:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   1.1s     22f ( 3%)  0.00fps Trem:   0min  11mb  A-V:0.000 [2711:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   1.1s     23f ( 3%)  0.00fps Trem:   0min  12mb  A-V:0.000 [2691:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   1.2s     24f ( 3%)  0.00fps Trem:   0min  12mb  A-V:0.000 [2672:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   1.2s     25f ( 3%)  0.00fps Trem:   0min  13mb  A-V:0.000 [2655:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   1.3s     26f ( 3%)  0.00fps Trem:   0min  13mb  A-V:0.000 [2639:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   1.4s     27f ( 3%)  0.00fps Trem:   0min  14mb  A-V:0.000 [2624:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   1.4s     28f ( 4%)  0.00fps Trem:   0min  10mb  A-V:0.000 [2610:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   1.4s     29f ( 4%)  0.00fps Trem:   0min  11mb  A-V:0.000 [2599:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   1.5s     30f ( 4%) 29.33fps Trem:   0min  11mb  A-V:0.000 [2588:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   1.6s     31f ( 4%) 29.67fps Trem:   0min  12mb  A-V:0.000 [2578:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   1.6s     32f ( 4%) 29.91fps Trem:   0min  12mb  A-V:0.000 [2567:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   1.6s     33f ( 4%) 30.33fps Trem:   0min  12mb  A-V:0.000 [2558:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   1.7s     34f ( 4%) 30.71fps Trem:   0min  13mb  A-V:0.000 [2547:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   1.8s     35f ( 5%) 31.06fps Trem:   0min  10mb  A-V:0.000 [2538:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   1.8s     36f ( 5%) 31.50fps Trem:   0min  10mb  A-V:0.000 [2530:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   1.9s     37f ( 5%) 31.81fps Trem:   0min  11mb  A-V:0.000 [2522:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   1.9s     38f ( 5%) 32.18fps Trem:   0min  11mb  A-V:0.000 [2514:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   1.9s     39f ( 5%) 32.47fps Trem:   0min  11mb  A-V:0.000 [2506:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   2.0s     40f ( 5%) 31.80fps Trem:   0min  12mb  A-V:0.000 [2499:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   2.0s     41f ( 5%) 31.27fps Trem:   0min  12mb  A-V:0.000 [2493:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   2.1s     42f ( 6%) 30.86fps Trem:   0min  10mb  A-V:0.000 [2487:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   2.1s     43f ( 6%) 30.85fps Trem:   0min  10mb  A-V:0.000 [2481:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   2.2s     44f ( 6%) 30.88fps Trem:   0min  10mb  A-V:0.000 [2475:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   2.2s     45f ( 6%) 31.14fps Trem:   0min  11mb  A-V:0.000 [2471:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   2.3s     46f ( 6%) 31.42fps Trem:   0min  11mb  A-V:0.000 [2465:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   2.4s     47f ( 6%) 31.65fps Trem:   0min  11mb  A-V:0.000 [2462:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   2.4s     48f ( 6%) 31.73fps Trem:   0min  11mb  A-V:0.000 [2457:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   2.5s     49f ( 7%) 31.74fps Trem:   0min  10mb  A-V:0.000 [2453:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   2.5s     50f ( 7%) 31.69fps Trem:   0min  10mb  A-V:0.000 [2449:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   2.5s     51f ( 7%) 31.88fps Trem:   0min  10mb  A-V:0.000 [2445:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   2.6s     52f ( 7%) 31.96fps Trem:   0min  10mb  A-V:0.000 [2441:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   2.6s     53f ( 7%) 31.99fps Trem:   0min  11mb  A-V:0.000 [2438:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   2.7s     54f ( 7%) 32.09fps Trem:   0min  11mb  A-V:0.000 [2435:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   2.8s     55f ( 7%) 32.09fps Trem:   0min  11mb  A-V:0.000 [2431:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   2.8s     56f ( 8%) 32.13fps Trem:   0min  10mb  A-V:0.000 [2427:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   2.9s     57f ( 8%) 32.15fps Trem:   0min  10mb  A-V:0.000 [2424:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   2.9s     58f ( 8%) 32.15fps Trem:   0min  10mb  A-V:0.000 [2420:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   3.0s     59f ( 8%) 32.28fps Trem:   0min  10mb  A-V:0.000 [2416:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   3.0s     60f ( 8%) 32.17fps Trem:   0min  10mb  A-V:0.000 [2413:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   3.0s     61f ( 8%) 32.33fps Trem:   0min  11mb  A-V:0.000 [2409:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   3.1s     62f ( 8%) 32.36fps Trem:   0min  11mb  A-V:0.000 [2406:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   3.1s     63f ( 9%) 32.47fps Trem:   0min  10mb  A-V:0.000 [2403:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   3.2s     64f ( 9%) 32.45fps Trem:   0min  10mb  A-V:0.000 [2400:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   3.2s     65f ( 9%) 32.65fps Trem:   0min  10mb  A-V:0.000 [2396:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   3.3s     66f ( 9%) 32.67fps Trem:   0min  10mb  A-V:0.000 [2395:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   3.4s     67f ( 9%) 32.86fps Trem:   0min  10mb  A-V:0.000 [2390:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   3.4s     68f ( 9%) 33.03fps Trem:   0min  10mb  A-V:0.000 [2387:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   3.5s     69f ( 9%) 33.01fps Trem:   0min  10mb  A-V:0.000 [2384:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   3.5s     70f (10%) 33.21fps Trem:   0min   9mb  A-V:0.000 [2381:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   3.5s     71f (10%) 33.22fps Trem:   0min  10mb  A-V:0.000 [2377:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   3.6s     72f (10%) 33.35fps Trem:   0min  10mb  A-V:0.000 [2374:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   3.6s     73f (10%) 33.29fps Trem:   0min  10mb  A-V:0.000 [2372:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   3.7s     74f (10%) 33.44fps Trem:   0min  10mb  A-V:0.000 [2370:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   3.8s     75f (10%) 33.50fps Trem:   0min  10mb  A-V:0.000 [2367:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   3.8s     76f (10%) 33.60fps Trem:   0min  10mb  A-V:0.000 [2363:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   3.9s     77f (11%) 33.60fps Trem:   0min   9mb  A-V:0.000 [2361:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   3.9s     78f (11%) 33.68fps Trem:   0min  10mb  A-V:0.000 [2358:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   4.0s     79f (11%) 33.76fps Trem:   0min  10mb  A-V:0.000 [2355:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   4.0s     80f (11%) 33.73fps Trem:   0min  10mb  A-V:0.000 [2353:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   4.0s     81f (11%) 33.81fps Trem:   0min  10mb  A-V:0.000 [2351:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   4.1s     82f (11%) 33.80fps Trem:   0min  10mb  A-V:0.000 [2348:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   4.2s     83f (11%) 33.88fps Trem:   0min  10mb  A-V:0.000 [2346:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   4.2s     84f (12%) 33.91fps Trem:   0min   9mb  A-V:0.000 [2344:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   4.2s     85f (12%) 33.92fps Trem:   0min   9mb  A-V:0.000 [2342:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   4.3s     86f (12%) 33.90fps Trem:   0min  10mb  A-V:0.000 [2339:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   4.3s     87f (12%) 33.98fps Trem:   0min  10mb  A-V:0.000 [2336:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   4.4s     88f (12%) 34.08fps Trem:   0min  10mb  A-V:0.000 [2333:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   4.5s     89f (12%) 34.06fps Trem:   0min  10mb  A-V:0.000 [2331:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   4.5s     90f (12%) 34.19fps Trem:   0min  10mb  A-V:0.000 [2330:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   4.5s     91f (13%) 34.30fps Trem:   0min   9mb  A-V:0.000 [2328:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   4.6s     92f (13%) 34.35fps Trem:   0min   9mb  A-V:0.000 [2325:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   4.7s     93f (13%) 34.25fps Trem:   0min   9mb  A-V:0.000 [2323:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   4.7s     94f (13%) 34.32fps Trem:   0min  10mb  A-V:0.000 [2321:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   4.8s     95f (13%) 34.37fps Trem:   0min  10mb  A-V:0.000 [2319:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   4.8s     96f (13%) 34.31fps Trem:   0min  10mb  A-V:0.000 [2317:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   4.8s     97f (13%) 34.43fps Trem:   0min  10mb  A-V:0.000 [2315:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   4.9s     98f (14%) 34.45fps Trem:   0min   9mb  A-V:0.000 [2314:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   5.0s     99f (14%) 34.46fps Trem:   0min   9mb  A-V:0.000 [2312:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   5.0s    100f (14%) 34.54fps Trem:   0min   9mb  A-V:0.000 [2310:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   5.0s    101f (14%) 34.62fps Trem:   0min   9mb  A-V:0.000 [2308:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   5.1s    102f (14%) 34.74fps Trem:   0min  10mb  A-V:0.000 [2306:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   5.2s    103f (14%) 34.81fps Trem:   0min  10mb  A-V:0.000 [2304:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   5.2s    104f (14%) 34.90fps Trem:   0min  10mb  A-V:0.000 [2302:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   5.2s    105f (15%) 34.99fps Trem:   0min   9mb  A-V:0.000 [2300:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   5.3s    106f (15%) 35.04fps Trem:   0min   9mb  A-V:0.000 [2299:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   5.3s    107f (15%) 35.16fps Trem:   0min   9mb  A-V:0.000 [2298:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   5.4s    108f (15%) 35.12fps Trem:   0min   9mb  A-V:0.000 [2296:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   5.5s    109f (15%) 35.24fps Trem:   0min   9mb  A-V:0.000 [2294:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   5.5s    110f (15%) 35.31fps Trem:   0min  10mb  A-V:0.000 [2292:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   5.5s    111f (15%) 35.34fps Trem:   0min  10mb  A-V:0.000 [2290:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   5.6s    112f (16%) 35.47fps Trem:   0min   9mb  A-V:0.000 [2289:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   5.7s    113f (16%) 35.49fps Trem:   0min   9mb  A-V:0.000 [2287:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   5.7s    114f (16%) 35.56fps Trem:   0min   9mb  A-V:0.000 [2285:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   5.8s    115f (16%) 35.68fps Trem:   0min   9mb  A-V:0.000 [2283:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   5.8s    116f (16%) 35.74fps Trem:   0min   9mb  A-V:0.000 [2281:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   5.8s    117f (16%) 35.81fps Trem:   0min   9mb  A-V:0.000 [2279:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   5.9s    118f (16%) 35.87fps Trem:   0min  10mb  A-V:0.000 [2277:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   6.0s    119f (17%) 35.95fps Trem:   0min   9mb  A-V:0.000 [2276:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   6.0s    120f (17%) 36.01fps Trem:   0min   9mb  A-V:0.000 [2274:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   6.0s    121f (17%) 36.08fps Trem:   0min   9mb  A-V:0.000 [2273:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   6.1s    122f (17%) 36.12fps Trem:   0min   9mb  A-V:0.000 [2271:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   6.2s    123f (17%) 36.08fps Trem:   0min   9mb  A-V:0.000 [2270:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   6.2s    124f (17%) 36.19fps Trem:   0min   9mb  A-V:0.000 [2268:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   6.2s    125f (17%) 36.16fps Trem:   0min   9mb  A-V:0.000 [2266:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   6.3s    126f (18%) 36.23fps Trem:   0min   9mb  A-V:0.000 [2265:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   6.3s    127f (18%) 36.22fps Trem:   0min   9mb  A-V:0.000 [2263:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   6.4s    128f (18%) 36.26fps Trem:   0min   9mb  A-V:0.000 [2261:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   6.5s    129f (18%) 36.34fps Trem:   0min   9mb  A-V:0.000 [2260:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   6.5s    130f (18%) 36.42fps Trem:   0min   9mb  A-V:0.000 [2258:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   6.5s    131f (18%) 36.53fps Trem:   0min   9mb  A-V:0.000 [2257:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   6.6s    132f (18%) 36.46fps Trem:   0min   9mb  A-V:0.000 [2254:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   6.7s    133f (19%) 36.62fps Trem:   0min   9mb  A-V:0.000 [2261:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   6.7s    134f (19%) 36.69fps Trem:   0min   9mb  A-V:0.000 [2259:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   6.8s    135f (19%) 36.73fps Trem:   0min   9mb  A-V:0.000 [2257:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   6.8s    136f (19%) 36.72fps Trem:   0min   9mb  A-V:0.000 [2256:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   6.8s    137f (19%) 36.78fps Trem:   0min   9mb  A-V:0.000 [2255:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   6.9s    138f (19%) 36.82fps Trem:   0min   9mb  A-V:0.000 [2254:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   7.0s    139f (19%) 36.76fps Trem:   0min   9mb  A-V:0.000 [2252:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   7.0s    140f (20%) 36.63fps Trem:   0min   9mb  A-V:0.000 [2251:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   7.0s    141f (20%) 36.67fps Trem:   0min   9mb  A-V:0.000 [2249:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   7.1s    142f (20%) 36.59fps Trem:   0min   9mb  A-V:0.000 [2247:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   7.2s    143f (20%) 36.62fps Trem:   0min   9mb  A-V:0.000 [2246:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   7.2s    144f (20%) 36.58fps Trem:   0min   9mb  A-V:0.000 [2244:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   7.2s    145f (20%) 36.61fps Trem:   0min   9mb  A-V:0.000 [2243:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   7.3s    146f (20%) 36.64fps Trem:   0min   9mb  A-V:0.000 [2242:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   7.3s    147f (21%) 36.69fps Trem:   0min   9mb  A-V:0.000 [2240:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   7.4s    148f (21%) 36.63fps Trem:   0min   9mb  A-V:0.000 [2239:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   7.5s    149f (21%) 36.65fps Trem:   0min   9mb  A-V:0.000 [2237:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   7.5s    150f (21%) 36.60fps Trem:   0min   9mb  A-V:0.000 [2236:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   7.5s    151f (21%) 36.50fps Trem:   0min   9mb  A-V:0.000 [2235:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   7.6s    152f (21%) 36.50fps Trem:   0min   9mb  A-V:0.000 [2233:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   7.7s    153f (21%) 36.45fps Trem:   0min   9mb  A-V:0.000 [2231:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   7.7s    154f (22%) 36.47fps Trem:   0min   9mb  A-V:0.000 [2230:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   7.8s    155f (22%) 36.50fps Trem:   0min   9mb  A-V:0.000 [2228:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   7.8s    156f (22%) 36.57fps Trem:   0min   9mb  A-V:0.000 [2227:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   7.8s    157f (22%) 36.50fps Trem:   0min   9mb  A-V:0.000 [2225:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   7.9s    158f (22%) 36.55fps Trem:   0min   9mb  A-V:0.000 [2223:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   8.0s    159f (22%) 36.46fps Trem:   0min   9mb  A-V:0.000 [2221:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   8.0s    160f (22%) 36.53fps Trem:   0min   9mb  A-V:0.000 [2220:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   8.1s    161f (23%) 36.53fps Trem:   0min   9mb  A-V:0.000 [2218:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   8.1s    162f (23%) 36.55fps Trem:   0min   9mb  A-V:0.000 [2216:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   8.2s    163f (23%) 36.59fps Trem:   0min   9mb  A-V:0.000 [2215:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   8.2s    164f (23%) 36.66fps Trem:   0min   9mb  A-V:0.000 [2214:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   8.2s    165f (23%) 36.74fps Trem:   0min   9mb  A-V:0.000 [2212:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   8.3s    166f (23%) 36.71fps Trem:   0min   9mb  A-V:0.000 [2210:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   8.3s    167f (23%) 36.76fps Trem:   0min   9mb  A-V:0.000 [2209:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   8.4s    168f (24%) 36.75fps Trem:   0min   9mb  A-V:0.000 [2208:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   8.4s    169f (24%) 36.78fps Trem:   0min   9mb  A-V:0.000 [2206:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   8.5s    170f (24%) 36.82fps Trem:   0min   9mb  A-V:0.000 [2205:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   8.6s    171f (24%) 36.81fps Trem:   0min   9mb  A-V:0.000 [2203:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   8.6s    172f (24%) 36.75fps Trem:   0min   9mb  A-V:0.000 [2202:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   8.7s    173f (24%) 36.61fps Trem:   0min   9mb  A-V:0.000 [2200:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   8.7s    174f (24%) 36.66fps Trem:   0min   9mb  A-V:0.000 [2199:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   8.8s    175f (25%) 36.73fps Trem:   0min   9mb  A-V:0.000 [2197:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   8.8s    176f (25%) 36.78fps Trem:   0min   9mb  A-V:0.000 [2196:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   8.8s    177f (25%) 36.85fps Trem:   0min   9mb  A-V:0.000 [2195:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   8.9s    178f (25%) 36.93fps Trem:   0min   9mb  A-V:0.000 [2193:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   8.9s    179f (25%) 36.98fps Trem:   0min   9mb  A-V:0.000 [2191:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   9.0s    180f (25%) 37.05fps Trem:   0min   9mb  A-V:0.000 [2190:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   9.1s    181f (25%) 37.11fps Trem:   0min   9mb  A-V:0.000 [2188:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   9.1s    182f (26%) 37.07fps Trem:   0min   9mb  A-V:0.000 [2187:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   9.2s    183f (26%) 37.04fps Trem:   0min   9mb  A-V:0.000 [2185:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   9.2s    184f (26%) 37.10fps Trem:   0min   9mb  A-V:0.000 [2184:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   9.2s    185f (26%) 37.19fps Trem:   0min   9mb  A-V:0.000 [2183:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   9.3s    186f (26%) 37.24fps Trem:   0min   9mb  A-V:0.000 [2181:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   9.3s    187f (26%) 37.30fps Trem:   0min   9mb  A-V:0.000 [2180:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   9.4s    188f (26%) 37.33fps Trem:   0min   9mb  A-V:0.000 [2178:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   9.4s    189f (27%) 37.36fps Trem:   0min   9mb  A-V:0.000 [2177:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   9.5s    190f (27%) 37.37fps Trem:   0min   9mb  A-V:0.000 [2175:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   9.6s    191f (27%) 37.37fps Trem:   0min   9mb  A-V:0.000 [2174:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   9.6s    192f (27%) 37.44fps Trem:   0min   9mb  A-V:0.000 [2172:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   9.7s    193f (27%) 37.50fps Trem:   0min   9mb  A-V:0.000 [2171:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   9.7s    194f (27%) 37.50fps Trem:   0min   9mb  A-V:0.000 [2169:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   9.8s    195f (27%) 37.55fps Trem:   0min   9mb  A-V:0.000 [2168:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   9.8s    196f (28%) 37.58fps Trem:   0min   9mb  A-V:0.000 [2166:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   9.8s    197f (28%) 37.65fps Trem:   0min   9mb  A-V:0.000 [2164:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   9.9s    198f (28%) 37.67fps Trem:   0min   9mb  A-V:0.000 [2163:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:   9.9s    199f (28%) 37.70fps Trem:   0min   9mb  A-V:0.000 [2161:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  10.0s    200f (28%) 37.75fps Trem:   0min   9mb  A-V:0.000 [2159:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  10.1s    201f (28%) 37.73fps Trem:   0min   9mb  A-V:0.000 [2157:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  10.1s    202f (28%) 37.67fps Trem:   0min   9mb  A-V:0.000 [2156:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  10.2s    203f (29%) 37.71fps Trem:   0min   9mb  A-V:0.000 [2154:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  10.2s    204f (29%) 37.71fps Trem:   0min   9mb  A-V:0.000 [2153:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  10.2s    205f (29%) 37.66fps Trem:   0min   9mb  A-V:0.000 [2151:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  10.3s    206f (29%) 37.70fps Trem:   0min   9mb  A-V:0.000 [2149:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  10.3s    207f (29%) 37.65fps Trem:   0min   9mb  A-V:0.000 [2148:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  10.4s    208f (29%) 37.67fps Trem:   0min   9mb  A-V:0.000 [2146:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  10.4s    209f (29%) 37.72fps Trem:   0min   9mb  A-V:0.000 [2144:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  10.5s    210f (30%) 37.78fps Trem:   0min   8mb  A-V:0.000 [2143:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  10.6s    211f (30%) 37.75fps Trem:   0min   8mb  A-V:0.000 [2141:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  10.6s    212f (30%) 37.80fps Trem:   0min   9mb  A-V:0.000 [2140:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  10.7s    213f (30%) 37.85fps Trem:   0min   9mb  A-V:0.000 [2138:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  10.7s    214f (30%) 37.83fps Trem:   0min   9mb  A-V:0.000 [2137:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  10.8s    215f (30%) 37.84fps Trem:   0min   9mb  A-V:0.000 [2135:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  10.8s    216f (30%) 37.90fps Trem:   0min   9mb  A-V:0.000 [2134:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  10.8s    217f (31%) 37.90fps Trem:   0min   8mb  A-V:0.000 [2132:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  10.9s    218f (31%) 37.91fps Trem:   0min   8mb  A-V:0.000 [2131:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  10.9s    219f (31%) 37.95fps Trem:   0min   8mb  A-V:0.000 [2130:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  11.0s    220f (31%) 38.00fps Trem:   0min   9mb  A-V:0.000 [2128:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  11.1s    221f (31%) 37.93fps Trem:   0min   9mb  A-V:0.000 [2127:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  11.1s    222f (31%) 37.95fps Trem:   0min   9mb  A-V:0.000 [2125:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  11.2s    223f (31%) 38.00fps Trem:   0min   9mb  A-V:0.000 [2123:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  11.2s    224f (32%) 37.98fps Trem:   0min   8mb  A-V:0.000 [2122:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  11.2s    225f (32%) 37.98fps Trem:   0min   8mb  A-V:0.000 [2121:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  11.3s    226f (32%) 38.01fps Trem:   0min   8mb  A-V:0.000 [2119:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  11.3s    227f (32%) 38.07fps Trem:   0min   8mb  A-V:0.000 [2118:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  11.4s    228f (32%) 38.13fps Trem:   0min   9mb  A-V:0.000 [2116:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  11.4s    229f (32%) 38.12fps Trem:   0min   9mb  A-V:0.000 [2114:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  11.5s    230f (32%) 38.14fps Trem:   0min   9mb  A-V:0.000 [2112:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  11.6s    231f (33%) 38.16fps Trem:   0min   8mb  A-V:0.000 [2111:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  11.6s    232f (33%) 38.17fps Trem:   0min   8mb  A-V:0.000 [2109:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  11.7s    233f (33%) 38.20fps Trem:   0min   8mb  A-V:0.000 [2108:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  11.7s    234f (33%) 38.22fps Trem:   0min   8mb  A-V:0.000 [2106:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  11.8s    235f (33%) 38.22fps Trem:   0min   8mb  A-V:0.000 [2105:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  11.8s    236f (33%) 38.19fps Trem:   0min   8mb  A-V:0.000 [2103:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  11.8s    237f (33%) 38.23fps Trem:   0min   9mb  A-V:0.000 [2101:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  11.9s    238f (34%) 38.18fps Trem:   0min   8mb  A-V:0.000 [2100:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  11.9s    239f (34%) 38.20fps Trem:   0min   8mb  A-V:0.000 [2098:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  12.0s    240f (34%) 38.20fps Trem:   0min   8mb  A-V:0.000 [2097:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  12.1s    241f (34%) 38.24fps Trem:   0min   8mb  A-V:0.000 [2095:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  12.1s    242f (34%) 38.20fps Trem:   0min   8mb  A-V:0.000 [2093:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  12.2s    243f (34%) 38.19fps Trem:   0min   8mb  A-V:0.000 [2092:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  12.2s    244f (34%) 38.20fps Trem:   0min   8mb  A-V:0.000 [2090:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  12.2s    245f (35%) 38.13fps Trem:   0min   8mb  A-V:0.000 [2088:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  12.3s    246f (35%) 38.18fps Trem:   0min   8mb  A-V:0.000 [2087:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  12.3s    247f (35%) 38.21fps Trem:   0min   8mb  A-V:0.000 [2086:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  12.4s    248f (35%) 38.18fps Trem:   0min   8mb  A-V:0.000 [2084:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  12.4s    249f (35%) 38.21fps Trem:   0min   8mb  A-V:0.000 [2082:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  12.5s    250f (35%) 38.26fps Trem:   0min   8mb  A-V:0.000 [2081:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  12.6s    251f (35%) 38.26fps Trem:   0min   8mb  A-V:0.000 [2079:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  12.6s    252f (36%) 38.26fps Trem:   0min   8mb  A-V:0.000 [2078:0]
# ...
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  30.9s    617f (88%) 42.60fps Trem:   0min   6mb  A-V:0.000 [1526:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  30.9s    618f (88%) 42.62fps Trem:   0min   6mb  A-V:0.000 [1524:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  30.9s    619f (88%) 42.59fps Trem:   0min   6mb  A-V:0.000 [1523:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  31.0s    620f (88%) 42.60fps Trem:   0min   6mb  A-V:0.000 [1521:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  31.1s    621f (88%) 42.58fps Trem:   0min   6mb  A-V:0.000 [1520:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  31.1s    622f (88%) 42.60fps Trem:   0min   6mb  A-V:0.000 [1519:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  31.1s    623f (89%) 42.62fps Trem:   0min   6mb  A-V:0.000 [1517:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  31.2s    624f (89%) 42.63fps Trem:   0min   6mb  A-V:0.000 [1516:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  31.2s    625f (89%) 42.66fps Trem:   0min   6mb  A-V:0.000 [1515:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  31.3s    626f (89%) 42.68fps Trem:   0min   6mb  A-V:0.000 [1513:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  31.4s    627f (89%) 42.65fps Trem:   0min   6mb  A-V:0.000 [1512:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  31.4s    628f (89%) 42.65fps Trem:   0min   6mb  A-V:0.000 [1511:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  31.4s    629f (89%) 42.64fps Trem:   0min   6mb  A-V:0.000 [1509:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  31.5s    630f (90%) 42.65fps Trem:   0min   6mb  A-V:0.000 [1508:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  31.6s    631f (90%) 42.67fps Trem:   0min   6mb  A-V:0.000 [1507:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  31.6s    632f (90%) 42.68fps Trem:   0min   6mb  A-V:0.000 [1505:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  31.6s    633f (90%) 42.68fps Trem:   0min   6mb  A-V:0.000 [1504:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  31.7s    634f (90%) 42.65fps Trem:   0min   6mb  A-V:0.000 [1503:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  31.8s    635f (90%) 42.67fps Trem:   0min   6mb  A-V:0.000 [1501:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  31.8s    636f (90%) 42.68fps Trem:   0min   6mb  A-V:0.000 [1500:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  31.9s    637f (91%) 42.71fps Trem:   0min   6mb  A-V:0.000 [1499:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  31.9s    638f (91%) 42.73fps Trem:   0min   6mb  A-V:0.000 [1497:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  31.9s    639f (91%) 42.75fps Trem:   0min   6mb  A-V:0.000 [1496:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  32.0s    640f (91%) 42.75fps Trem:   0min   6mb  A-V:0.000 [1495:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  32.0s    641f (91%) 42.74fps Trem:   0min   6mb  A-V:0.000 [1493:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  32.1s    642f (91%) 42.73fps Trem:   0min   6mb  A-V:0.000 [1492:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  32.1s    643f (91%) 42.75fps Trem:   0min   6mb  A-V:0.000 [1491:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  32.2s    644f (92%) 42.76fps Trem:   0min   6mb  A-V:0.000 [1489:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  32.2s    645f (92%) 42.79fps Trem:   0min   6mb  A-V:0.000 [1488:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  32.3s    646f (92%) 42.76fps Trem:   0min   6mb  A-V:0.000 [1487:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  32.4s    647f (92%) 42.76fps Trem:   0min   6mb  A-V:0.000 [1485:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  32.4s    648f (92%) 42.78fps Trem:   0min   6mb  A-V:0.000 [1484:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  32.5s    649f (92%) 42.80fps Trem:   0min   6mb  A-V:0.000 [1483:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  32.5s    650f (92%) 42.82fps Trem:   0min   6mb  A-V:0.000 [1481:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  32.5s    651f (93%) 42.83fps Trem:   0min   6mb  A-V:0.000 [1480:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  32.6s    652f (93%) 42.82fps Trem:   0min   6mb  A-V:0.000 [1479:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  32.6s    653f (93%) 42.82fps Trem:   0min   6mb  A-V:0.000 [1477:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  32.7s    654f (93%) 42.80fps Trem:   0min   6mb  A-V:0.000 [1476:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  32.8s    655f (93%) 42.82fps Trem:   0min   6mb  A-V:0.000 [1475:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  32.8s    656f (93%) 42.85fps Trem:   0min   6mb  A-V:0.000 [1473:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  32.9s    657f (93%) 42.87fps Trem:   0min   6mb  A-V:0.000 [1472:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  32.9s    658f (94%) 42.87fps Trem:   0min   6mb  A-V:0.000 [1471:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  33.0s    659f (94%) 42.85fps Trem:   0min   6mb  A-V:0.000 [1469:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  33.0s    660f (94%) 42.87fps Trem:   0min   6mb  A-V:0.000 [1468:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  33.0s    661f (94%) 42.90fps Trem:   0min   6mb  A-V:0.000 [1468:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  33.1s    662f (94%) 42.91fps Trem:   0min   6mb  A-V:0.000 [1467:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  33.1s    663f (94%) 42.94fps Trem:   0min   6mb  A-V:0.000 [1465:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  33.2s    664f (94%) 42.95fps Trem:   0min   6mb  A-V:0.000 [1464:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  33.2s    665f (95%) 42.92fps Trem:   0min   6mb  A-V:0.000 [1463:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  33.3s    666f (95%) 42.92fps Trem:   0min   6mb  A-V:0.000 [1461:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  33.4s    667f (95%) 42.93fps Trem:   0min   6mb  A-V:0.000 [1460:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  33.4s    668f (95%) 42.96fps Trem:   0min   6mb  A-V:0.000 [1459:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  33.5s    669f (95%) 42.98fps Trem:   0min   6mb  A-V:0.000 [1457:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  33.5s    670f (95%) 42.93fps Trem:   0min   6mb  A-V:0.000 [1456:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  33.5s    671f (95%) 42.91fps Trem:   0min   6mb  A-V:0.000 [1455:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  33.6s    672f (96%) 42.93fps Trem:   0min   6mb  A-V:0.000 [1453:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  33.6s    673f (96%) 42.95fps Trem:   0min   6mb  A-V:0.000 [1452:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  33.7s    674f (96%) 42.97fps Trem:   0min   6mb  A-V:0.000 [1451:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  33.8s    675f (96%) 42.99fps Trem:   0min   6mb  A-V:0.000 [1449:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  33.8s    676f (96%) 42.92fps Trem:   0min   6mb  A-V:0.000 [1448:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  33.9s    677f (96%) 42.89fps Trem:   0min   6mb  A-V:0.000 [1447:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  33.9s    678f (96%) 42.90fps Trem:   0min   6mb  A-V:0.000 [1446:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  34.0s    679f (97%) 42.90fps Trem:   0min   6mb  A-V:0.000 [1444:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  34.0s    680f (97%) 42.93fps Trem:   0min   6mb  A-V:0.000 [1443:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  34.0s    681f (97%) 42.94fps Trem:   0min   6mb  A-V:0.000 [1442:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  34.1s    682f (97%) 42.96fps Trem:   0min   6mb  A-V:0.000 [1440:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  34.1s    683f (97%) 42.99fps Trem:   0min   6mb  A-V:0.000 [1439:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  34.2s    684f (97%) 43.01fps Trem:   0min   6mb  A-V:0.000 [1438:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  34.2s    685f (97%) 43.02fps Trem:   0min   6mb  A-V:0.000 [1436:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  34.3s    686f (98%) 43.01fps Trem:   0min   5mb  A-V:0.000 [1435:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  34.4s    687f (98%) 43.00fps Trem:   0min   6mb  A-V:0.000 [1434:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  34.4s    688f (98%) 43.01fps Trem:   0min   6mb  A-V:0.000 [1433:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  34.5s    689f (98%) 43.02fps Trem:   0min   6mb  A-V:0.000 [1431:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  34.5s    690f (98%) 43.04fps Trem:   0min   6mb  A-V:0.000 [1430:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  34.5s    691f (98%) 43.06fps Trem:   0min   6mb  A-V:0.000 [1429:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  34.6s    692f (98%) 43.06fps Trem:   0min   6mb  A-V:0.000 [1428:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  34.6s    693f (99%) 43.06fps Trem:   0min   5mb  A-V:0.000 [1426:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  34.7s    694f (99%) 43.05fps Trem:   0min   5mb  A-V:0.000 [1425:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  34.8s    695f (99%) 43.07fps Trem:   0min   5mb  A-V:0.000 [1424:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  34.8s    696f (99%) 43.09fps Trem:   0min   5mb  A-V:0.000 [1423:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  34.9s    697f (99%) 43.10fps Trem:   0min   5mb  A-V:0.000 [1421:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  34.9s    698f (99%) 43.12fps Trem:   0min   5mb  A-V:0.000 [1420:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  35.0s    699f (99%) 43.09fps Trem:   0min   5mb  A-V:0.000 [1419:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  35.0s    700f (100%) 43.08fps Trem:   0min   5mb  A-V:0.000 [1418:0]
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.format is not set
# [msmpeg4v2 @ 0x101bb4fe0]AVFrame.width or height is not set
# Pos:  35.0s    701f (100%) 43.10fps Trem:   0min   5mb  A-V:0.000 [1416:0]
#
# Skipping frame!
# Pos:  35.0s    702f (100%) 43.16fps Trem:   0min   5mb  A-V:0.000 [1416:0]
#
# Flushing video frames.
# Writing index...
# Writing header...
# ODML: vprp aspect is 16384:16384.
#
# Video stream: 1416.812 kbit/s  (177101 B/s)  size: 6207406 bytes  35.050 secs  702 frames

# %%
# %cd ..
# Out:
# /Users/draflorencia/Documents/Adriano/simulaciones/New_Programs/Foreign_Notebooks

# %%
# !mkdir SHY10_Statistics_01

# %%
# %cd SHY10_Statistics_01/
# Out:
# /Users/draflorencia/Documents/Adriano/simulaciones/New_Programs/Foreign_Notebooks/SHY10_Statistics_01/SHY10_Statistics_01

# %% [markdown]
# ### Ubicarnos en el directorio donde guardar los archivos...

# %%
# !pwd
# Out:
# /Users/adrianovaldesgomez/Documents/Adriano_Programming

# %%
# !mkdir Y10_30062018_1609

# %%
# %cd Y10_30062018_1609/
# Out:
# /Users/adrianovaldesgomez/Documents/Adriano_Programming/Y10_30062018_1609

# %%
import time

# %%
#Vamos a usar esta plantilla para calcular el desplasamiento medio cuadratico
#en el caso de un campo externo con cuatro puntos criticos
#el ensamble parte del polo norte explotando la simetria del problema

start_time = time.time()
#Paramtreos de la simulacion
D = 1e-1
dt = np.log(2)*1e-3
v0 = 5.0*np.sqrt(2*D)*dt
#v0 = 0.

#dist_uni = polo_n(10000,1.)

dist_uni = obs_uniforme(3000, 1., 0)


Nt = 10000


#plot_potential(dist_uni,0,0,0)
rs = dist_uni




#Variables iniciales para el analisis estadistico
ht0, mt0, vt0 = mean_var_hist_theta(rs)
#hp0, mp0, vp0 = mean_var_hist_phis(rs)
mean_thetas_t = [mt0]
var_thetas_t = [vt0]
#mean_phis_t = [mp0]
#var_phis_t = [vp0]
histograma_thetas_t = [ht0]
#histograma_phis_t = [hp0]




#Variables para el analisis estadistico
#mt0,vt0 = mean_var_theta(rs)
#mp0,vp0 = mean_var_phis(rs)
#mean_thetas_t = [mt0]
#var_thetas_t = [vt0]
#mean_phis_t = [mp0]
#var_phis_t = [vp0]
#histograma_thetas_t = []
#histograma_phis_t = []



for i in range(Nt):
         
        nuevas_pos = act_n_field(rs, v0)
        #plot_potential(nuevas_pos, 0, 0, i + 1)
        rs = nuevas_pos
        ht, mt, vt = mean_var_hist_theta(rs)
        #hp, mp, vp = mean_var_hist_phis(rs)
        histograma_thetas_t.append(ht)
        #histograma_phis_t.append(hp)
        #mean_thetas_t.append(mt)
        #var_thetas_t.append(vt)
        #mean_phis_t.append(mp)
        #var_phis_t.append(vp)
        
        
        
np.savetxt("Y10UD_Hist_Theta_t.txt", histograma_thetas_t)
#np.savetxt("Y10UD_Hist_Phi_t.txt", histograma_phis_t)
#np.savetxt("Y10UD_Mean_Theta_t.txt", mean_thetas_t)
#np.savetxt("Y10UD_Mean_phi_t.txt", mean_phis_t)
#np.savetxt("Y10UD_Var_Theta_t.txt", var_thetas_t)
#np.savetxt("Y10UD_Var_Phi_t.txt", var_phis_t)



print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 6069.258764028549 seconds ---

# %%
15267.2725/3600
# Out:
# 4.240909027777778

# %% [markdown]
# ### Plotting

# %%
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
#%matplotlib inline

# %%
# !pwd
# Out:
# /Users/draflorencia/Documents/Adriano/simulaciones/New_Programs/Foreign_Notebooks

# %%
# %cd SHY10_Statistics_01/
# Out:
# /Users/draflorencia/Documents/Adriano/simulaciones/New_Programs/Foreign_Notebooks/SHY10_Statistics_01

# %% [markdown]
# Cuidado al importar los histogramas que pesan como 5 GB cada uno!!!

# %%
# %ls
# Out:
# TopCLSphericalHarmonicYl1m0.png  Y10UD_Mean_phi_t.txt
# Y10UD_Hist_Phi_t.txt             Y10UD_Var_Phi_t.txt
# Y10UD_Hist_Theta_t.txt           Y10UD_Var_Theta_t.txt
# Y10UD_Mean_Theta_t.txt

# %%
# %pwd
# Out:
# u'/Users/adrianovaldesgomez/Documents'

# %%
# %cd Adriano_Programming/Y10_28_10_2017/
# Out:
# /Users/adrianovaldesgomez/Documents/Adriano_Programming/Y10_28_10_2017

# %%
x1 = np.loadtxt("Y10UD_Hist_Theta_t.txt")
#x2 = np.loadtxt("Y10DU_Hist_Phi_t.txt")
#x3 = np.loadtxt("Y10DU_Mean_Theta_t.txt")
#x4 = np.loadtxt("Y10DU_Mean_phi_t.txt")
#x5 = np.loadtxt("Y10DU_Var_Theta_t.txt")
#x6 = np.loadtxt("Y10DU_Var_Phi_t.txt")

# %% [markdown]
# Aquí vamos a importar todos los archivos para los dos primeros momentos de $\theta$ y $\phi$, para comparar simulatáneamente las diferencias.

# %%
import numpy as np

# %%
# %cd ..
# %cd SHY30_Statistics_01/
# !ls
# Out:
# /Users/draflorencia/Documents/Adriano/simulaciones/New_Programs
# /Users/draflorencia/Documents/Adriano/simulaciones/New_Programs/SHY30_Statistics_01
# Y30_Hist_Phi_t.txt        Y30_Hist_Theta_tinfty.png Y30_Var_Phi_t.png
# Y30_Hist_Phi_t0.png       Y30_Mean_Phi_t.png        Y30_Var_Phi_t.txt
# Y30_Hist_Phi_tinfty.png   Y30_Mean_Theta_t.png      Y30_Var_Theta_t.png
# Y30_Hist_Theta_t.txt      Y30_Mean_Theta_t.txt      Y30_Var_Theta_t.txt
# Y30_Hist_Theta_t0.png     Y30_Mean_phi_t.txt

# %%
# !pwd
# %cd ..
# !pwd
# Out:
# /Users/draflorencia/Documents/Adriano/simulaciones/New_Programs/SHY30_Statistics_01
# /Users/draflorencia/Documents/Adriano/simulaciones/New_Programs
# /Users/draflorencia/Documents/Adriano/simulaciones/New_Programs

# %%
# %cd SHY30_Statistics_01/
TMY30 = np.loadtxt("Y30_Mean_Theta_t.txt")
TVY30 = np.loadtxt("Y30_Var_Theta_t.txt")
# Out:
# /Users/draflorencia/Documents/Adriano/simulaciones/New_Programs/SHY30_Statistics_01

# %%
# %cd ..
# Out:
# /Users/draflorencia/Documents/Adriano/simulaciones/New_Programs

# %%
# %cd Y10/
# Out:
# /Users/draflorencia/Documents/Adriano/simulaciones/New_Programs/Foreign_Notebooks

# %%
# !pwd
# Out:
# /Users/adrianovaldesgomez/Documents/Adriano_Programming/Y10_28_10_2017

# %%
# %ls
# Out:
# TopCLSphericalHarmonicYl1m0.png  Y10UD_Mean_phi_t.txt
# Y10UD_Hist_Phi_t.txt             Y10UD_Var_Phi_t.txt
# Y10UD_Hist_Theta_t.txt           Y10UD_Var_Theta_t.txt
# Y10UD_Mean_Theta_t.txt

# %%
#%cd SHY10_Statistics_01/
#TMY101 = np.loadtxt("Y10UD_Mean_Theta_t.txt")
#TVY10 = np.loadtxt("Y10UD_Var_Theta_t.txt")
#%cd ..
#%cd SHY20_Statistics_01/
TMY10 = np.loadtxt("Y10DU_Mean_Theta_t.txt")
TVY10 = np.loadtxt("Y10DU_Var_Theta_t.txt")
#%cd ..
#cd SHY30_Statistics_01/
#TMY30 = np.loadtxt("Y30_Mean_Theta_t.txt")
#TVY30 = np.loadtxt("Y30_Var_Theta_t.txt")
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-16-4d6c3d210cfe> in <module>()
#       4 #%cd ..
#       5 #%cd SHY20_Statistics_01/
# ----> 6 TMY10 = np.loadtxt("Y10DU_Mean_Theta_t.txt")
#       7 TVY10 = np.loadtxt("Y10DU_Var_Theta_t.txt")
#       8 #%cd ..
#
# /Users/adrianovaldesgomez/anaconda/lib/python2.7/site-packages/numpy/lib/npyio.pyc in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     689                 fh = iter(bz2.BZ2File(fname))
#     690             elif sys.version_info[0] == 2:
# --> 691                 fh = iter(open(fname, 'U'))
#     692             else:
#     693                 fh = iter(open(fname))
#
# IOError: [Errno 2] No such file or directory: 'Y10DU_Mean_Theta_t.txt'

# %%
x1= histograma_thetas_t

# %%
# %matplotlib inline

# %%
xpot = np.linspace(0,np.pi,1000)
ypot = v0*np.sqrt(3./(4*np.pi))*np.cos(xpot)

# %%
fig = plt.figure(figsize=(7,5))
ax = fig.add_subplot(111)
n,bins, rectangles = plt.hist(x1[0], bins = 100, normed = True, #
color = "g", alpha = 0.8, edgecolor='black', linewidth=1.2)
fig.canvas.draw()
plt.xlabel(r"$\theta$", fontsize = 19)
#plt.ylabel(r"$P(\theta,t = t_0| \theta_0, t_0)$", fontsize = 18)
#plt.legend(loc = 1, fontsize = 14)
plt.title(r"$P(\theta,t = t_0| \theta_0, t_0)$", fontsize = 16)
plt.plot(xpot,ypot, color = "r", linestyle = "-", label = r"$U(\theta) = Y_{1}^{0}(\theta, \phi)$")
plt.plot(xpot, 0.5*np.sin(xpot), color = "b", linestyle = "--",label = r"$\frac{1}{2}\,\sin{\theta}$")
plt.ylim(-1,2)
plt.xlim(0,np.pi)
plt.legend(loc=1, fontsize = 13)
plt.savefig("Y10_Hist_Theta_t0", dpi = 150)
plt.show()

# %%
Norm1 = 1159
D=1e-1
xt = np.linspace(0,np.pi,1000)
yt = (1./Norm1)*np.exp(-190*D*(np.sqrt(3./(4*np.pi)))*np.cos(xt))*np.sin(xt)

# %%
# %pwd
# Out:
# u'/Users/adrianovaldesgomez/Documents/Adriano_Programming/Y10_28_10_2017'

# %%
D=1e-1

# %%
theta = np.linspace(0,np.pi,1000)
#U0 = 5.0*np.sqrt(2*D)

# %%
#pot_Y10_int = (theta)/2. - 1/4.*np.sin(2*theta)
pot_Y10_int = -np.cos(theta)
coeff_pot_Y10 = np.sqrt(3./(4*np.pi))*2*v0/D
#p0_Y10_int = (1/9.70341e13)*np.exp(coeff_pot_Y10*pot_Y10_int)*np.sin(theta)
p0_Y10_int = (1./(3.723731e7))*np.exp(coeff_pot_Y10*pot_Y10_int)*np.sin(theta)
xpot_Y10 = np.linspace(0,np.pi,1000)
ypot_Y10 = v0*np.sqrt(3./(4*np.pi))*np.cos(xpot)/dt

# %%
fig = plt.figure(figsize = (7,5))
ax = fig.add_subplot(111)
n,bins, rectangles = plt.hist(x1[-1], bins = 100, normed = True, color = "g", #
alpha = .59, edgecolor='black', linewidth=1.2)
fig.canvas.draw()
plt.xlabel(r"$\theta$", fontsize = 15)
#plt.ylabel(r"$P(\theta,t = t_0| \theta_0, t_0)$", fontsize = 18)
#plt.legend(loc = 1, fontsize = 14)
plt.title(r"$P(\theta,t \to \infty | \theta_0, t_0)$", fontsize = 15)
plt.plot(xpot, 0.5*np.sin(xpot), color = "g", linestyle = "--",label = r"$P(\theta,0) = \frac{1}{2}\,\sin{\theta}$")

#plt.plot(theta, p0_Y10_int, label=r'$P(\theta, \infty) = N \,\exp{[-\Phi(\theta)]}$')
plt.fill_between(xt, yt,y2 = 0, color = 'darkblue', alpha = .350, label=r'$P(\theta, \infty) = N \,\exp{[-\Phi(\theta)]}$')

#plt.fill_between(theta, p0_Y10_int ,y2 = 0, color = '#778899', alpha = .750, label=r'$P(\theta, \infty) = N \,\exp{[-\Phi(\theta)]}$')
plt.xlim(0,np.pi)
plt.ylim(-1,3)
plt.plot(xpot, ypot_Y10, color = "r", label = r"$U(\theta) =U_0 Y_{1}^{0}(\theta, \phi)$")
plt.legend(loc=2, fontsize = 10)
#plt.savefig("Y10_Hist_Theta_tinf", dpi = 250)
plt.show()

# %% [markdown]
# ## Integramos la ecuación (estacionaria) transformada de Fokker-Planck con respecto a $\theta$

# %%
# !pwd
# Out:
# /Users/adrianovaldesgomez/Documents/Adriano_Programming

# %%
fig = plt.figure(figsize=(7,5))
ax = fig.add_subplot(111)
n,bins, rectangles = plt.hist(x2[0], bins = 100, normed = True, #
color = "b", alpha = 0.8)
fig.canvas.draw()
plt.plot(np.linspace(0,2*np.pi,100), (1./(2*np.pi))*np.ones(len(np.linspace(0,2*np.pi,100))), color = "r",#
label = r"$\phi(t) = \frac{1}{2\pi}$")
plt.xlabel(r"$\phi$", fontsize = 19)
plt.title(r"$P(\theta, \phi,t = t_0| \theta_0, \phi_0, t_0)$", fontsize = 16)
plt.ylim(0,1)
plt.xlim(0,2*np.pi)
plt.legend(loc = 1, fontsize = 15)
plt.savefig("Y10_Hist_Phi_t0", dpi = 150)
plt.show()

# %%
fig = plt.figure(figsize=(7,5))
ax = fig.add_subplot(111)
n,bins, rectangles = plt.hist(x2[0], bins = 100, normed = True, #
color = "b", alpha = 0.8)
fig.canvas.draw()
plt.plot(np.linspace(0,2*np.pi,100), (1./(2*np.pi))*np.ones(len(np.linspace(0,2*np.pi,100))), color = "r", #
label = r"$\phi(t) = \frac{1}{2\pi}$")
plt.xlabel(r"$\phi$", fontsize = 19)
plt.title(r"$P(\theta, \phi,t \to \infty | \theta_0, \phi_0, t_0)$", fontsize = 16)
plt.ylim(0,1)
plt.xlim(0,2*np.pi)
plt.legend(loc = 1, fontsize = 15)
plt.savefig("Y10_Hist_Phi_tinfty", dpi = 150)
plt.show()

# %%
tiempo = 0
dt = np.log(2)*1e-3
Nt = 5000
tiempos = [tiempo]
for i in range(Nt):
    tiempo = tiempo + dt
    tiempos.append(tiempo)
tiempos = np.array(tiempos)

# %%
from matplotlib import pyplot as plt

# %%
plt.rc('text', usetex=True)
plt.plot(tiempos, TMY101, color = 'g')
plt.plot(tiempos, np.pi/2*np.ones(len(tiempos)), color = "r", linestyle = "--", label = r"$\theta = \pi$")
plt.plot(tiempos, (2.8)*np.ones(len(tiempos)), color = "k", linestyle = "--", label = r"$\theta(t \to \infty)$")
#plt.plot(tiempos[:5800], np.arccos(np.exp(-14*D*np.array(tiempos[:5800]))))
#plt.plot(tiempos[:5800], np.pi/2*np.ones(len(tiempos[:5800])), color = 'r')
plt.xlabel(r'$t$', fontsize = 15)
plt.ylim(0,np.pi)
plt.ylabel(r'$\langle \theta(t) \rangle$', fontsize = 15)
plt.legend(loc = 4, fontsize = 15)
plt.savefig("Y10_Mean_Theta_t", dpi = 150)

# %%
plt.rc('text', usetex=True)
plt.plot(tiempos, x5, color = 'g')
plt.xlabel(r'$t$', fontsize = 15)
plt.ylabel(r'$\mbox{Var}\{\theta(t)\}$', fontsize = 15)
plt.ylim(0,np.pi + 0.5)
plt.savefig("Y10_Var_Theta_t", dpi = 150)

# %%
np.var(x1[0])
# Out:
# 0.46874064549509648

# %%
plt.rc('text', usetex=True)
plt.plot(tiempos, x6, color =  'b')
plt.plot(tiempos, np.pi*np.ones(len(tiempos)), color = "r", linestyle = "--")
plt.xlabel(r'$t$', fontsize = 15)
plt.ylabel(r'$$\langle \phi(t) \rangle$$', fontsize = 15)
plt.ylim(0,2*np.pi)
plt.savefig("Y10_Mean_Phi_t", dpi = 150)

# %%
plt.rc('text', usetex=True)
plt.plot(tiempos, x6 , color = 'b')
plt.plot(tiempos, np.sqrt((13/12.)*(np.pi**2))*np.ones(len(tiempos)), color = "r", label = r"$$")
plt.xlabel(r'$t$', fontsize = 15)
plt.ylabel(r'$$\mbox{Var}(\phi(t))$$', fontsize = 15)
plt.ylim(0,2*np.pi)
plt.savefig("Y10_Var_Phi_t", dpi = 150)

# %%
np.sqrt(np.var(x2[-1]))
# Out:
# 1.8197993863142048

# %%
np.sqrt((13/12.)*(np.pi**2))
# Out:
# 3.2698733055752283

# %%
type(x1)
# Out:
# numpy.ndarray

# %%
len(x1[0])
# Out:
# 10000

# %%
np.var?

# %%
Period_Chain = 2**(19937)-1

# %%
Period_Chain
# Out:
# ...

# %%
Period_Chain > 1e18
# Out:
# True
